# %%
import pandas as pd
import pulp
from pulp import GLPK
import numpy as np

# %%
df = pd.read_csv("Dea_data2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Company                                         25 non-null     object
#  1   Year                                            25 non-null     int64
#  2   GHG_Intensity                                   25 non-null     float64
#  3   Energy_Intensity_per_Sales                      25 non-null     float64
#  4   NonRenewable_Energy_Consumption_and_Production  25 non-null     float64
#  5   Water_Intensity_Per_Sales                       25 non-null     float64
#  6   NonRecycled_Waste_ration                        25 non-null     float64
#  7   ESG_Score                                       25 non-null     float64
#  8   GHG_1                                           25 non-null     float64
#  9   GHG_2                                           25 non-null     float64
#  10  GHG_3                                           25 non-null     float64
#  11  1_plus_2                                        25 non-null     float64
#  12  1_plus_2_plus_3                                 25 non-null     float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
df.replace(0, 0.01, inplace=True)
df.head()
# Out:
#           Company  Year  GHG_Intensity  Energy_Intensity_per_Sales  \
# 0  SONY US Equity  2023         283.35                       96.22
# 1  SONY US Equity  2022         255.60                       95.00
# 2  SONY US Equity  2021         283.36                       40.75
# 3  SONY US Equity  2020         237.57                       40.61
# 4  SONY US Equity  2019         263.10                       40.76
#
#    NonRenewable_Energy_Consumption_and_Production  Water_Intensity_Per_Sales  \
# 0                                            89.9                      0.010
# 1                                            95.1                      3.392
# 2                                            94.4                      6.784
# 3                                            95.8                     10.176
# 4                                            98.1                     13.568
#
#    NonRecycled_Waste_ration  ESG_Score  GHG_1  GHG_2   GHG_3  1_plus_2  \
# 0                       3.3       5.09   2.72   8.73  250.54     11.45
# 1                       2.0       5.03   2.63  12.28  227.68     14.92
# 2                       2.0       4.97   2.36  10.44  226.74     12.80
# 3                       2.1       4.79   2.41  15.22  190.47     17.63
# 4                       4.6       4.51   2.48  15.58  216.95     18.05
#
#    1_plus_2_plus_3
# 0           261.99
# 1           242.60
# 2           239.54
# 3           208.09
# 4           235.00

# %%
df.shape
# Out:
# (25, 13)

# %%
class DEA_models:
    def __init__(self):
        DEFALUT_inputs_t1 = np.array(df[df['Year'] == 2019][['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                                'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        DEFALUT_outputs_t1 = np.array(df[df['Year'] == 2019][['GHG_Intensity', 'ESG_Score']])
        self.num_dmus = DEFALUT_inputs_t1.shape[0]
        self.num_inputs = DEFALUT_inputs_t1.shape[1]
        self.num_outputs = DEFALUT_outputs_t1.shape[1]

        self.result_matrix = pd.DataFrame(columns=['SONY', 'APPL', 'DELL', 'HPE', 'SAMSUNG', 'EorT', 'Period'])
        self.Malquist_models = []
        self.Malquist_concepted_model=[]
        self.Malquist_primal_model=[]

        # for SBM model
        self.S_minus_list = []
        #self.S_plus_list = []
        self.rho_list = []
        self.SBM_result = pd.DataFrame(columns=['Conpany', 'Year', 'Rho'])

    # the Efficiency has been moved to function calculate_efficiency_from_concept
    # the calculate_efficiency is reused for the confirmation of the outliners   
    """
    def calculate_efficiency(self, inputs, outputs, reference_inputs, reference_outputs,i):
        model = pulp.LpProblem("Efficiency_Calculation", pulp.LpMaximize)
        lambdas = [pulp.LpVariable(f"lambda_{j}", lowBound=0) for j in range(self.num_dmus)]
        model += pulp.lpSum([lambdas[j] * reference_outputs[j, 0] for j in range(self.num_dmus)])
        for k in range(self.num_inputs):
            model += pulp.lpSum([lambdas[j] * reference_inputs[j, k] for j in range(self.num_dmus)]) <= inputs[i, k]
        model += pulp.lpSum(lambdas) == 0.1
        # model += pulp.lpSum(lambdas) == 1

        # collect models dor debug
        self.Malquist_models.append(model)
        
        model.solve()
            
        if model.status == pulp.LpStatusOptimal:
            self.efficiency_score = pulp.value(pulp.lpSum([lambdas[j] * reference_outputs[j, 0] for j in range(self.num_dmus)])) / outputs[i, 0]
        else:
            self.efficiency_score = -1
            
        return self.efficiency_score
    """

    def calculate_efficiency_from_concept(self, inputs, outputs, reference_inputs, reference_outputs, i):
        model = pulp.LpProblem("Efficiency_Calculation_from_concept", pulp.LpMinimize)

        lambdas = [pulp.LpVariable(f"lambda_{j}", lowBound=0) for j in range(self.num_dmus)]
        Theta = pulp.LpVariable("Theta", lowBound=0) 
   
        model += Theta
        for k in range(self.num_inputs):
            model += (pulp.lpSum([lambdas[j] * reference_inputs[j, k] for j in range(self.num_dmus)]) <= Theta * inputs[i, k])
        for k in range(self.num_outputs):
            model += (pulp.lpSum([lambdas[j] * reference_outputs[j, k] for j in range(self.num_dmus)]) >= outputs[i, k])

        self.Malquist_concepted_model.append(model)
        model.solve()

        if pulp.LpStatus[model.status] == "Optimal":
            efficiency_score = Theta.value()
        else:
            # change the default
            efficiency_score = 0

        return efficiency_score

    def CRS_InputOriented_Primal_equation(self, inputs, outputs, reference_inputs, reference_outputs, DMU_Index):

        lp_problem = pulp.LpProblem("Efficiency_Calculation_from_PrimalEquation", pulp.LpMaximize)
        v = [pulp.LpVariable(f"v_{i}", lowBound=0) for i in range(self.num_inputs)] 
        u = [pulp.LpVariable(f"u_{r}", lowBound=0) for r in range(self.num_outputs)]
        #print(lp_problem)
        lp_problem += pulp.lpSum(u[r] * reference_outputs[DMU_Index][r] for r in range(self.num_outputs))
        #print(lp_problem)
        for j in range(self.num_dmus):
            lp_problem += (
                pulp.lpSum(v[i] * reference_inputs[j, i] for i in range(self.num_inputs)) - pulp.lpSum(u[r] * outputs[j, r] for r in range(self.num_outputs)) >= 0
            )
        #print(lp_problem)
        lp_problem += pulp.lpSum(v[i] * inputs[DMU_Index][i] for i in range(self.num_inputs)) == 1
        #print(lp_problem)
        self.Malquist_primal_model.append(lp_problem)
        lp_problem.solve()

        if pulp.LpStatus[lp_problem.status] == "Optimal":
            efficiency_score = pulp.value(lp_problem.objective)
        else:
            efficiency_score = np.nan

        return efficiency_score

    def Primal_equation_test(self):
        effective_score_list = []
        self.test_model_catch = []
        for year_ in [2019, 2020, 2021, 2022]:
            in_t1, out_t1, in_t2, out_t2 = self.return_periods(year_)
            for Dmu_index in range(self.num_dmus):
                eff_t1_t1 = self.CRS_InputOriented_Primal_equation(in_t1, out_t1, in_t1, out_t1, Dmu_index)
                eff_t1_t2 = self.CRS_InputOriented_Primal_equation(in_t1, out_t1, in_t2, out_t2, Dmu_index)
                eff_t2_t1 = self.CRS_InputOriented_Primal_equation(in_t2, out_t2, in_t1, out_t1, Dmu_index)
                eff_t2_t2 = self.CRS_InputOriented_Primal_equation(in_t2, out_t2, in_t2, out_t2, Dmu_index)
                
                if all(v is not np.nan for v in [eff_t1_t1, eff_t2_t2, eff_t1_t2, eff_t2_t1]):
                    EC = eff_t2_t2 / eff_t1_t1 if eff_t1_t1 != np.nan else np.nan
                    TC = np.sqrt((eff_t1_t2 * eff_t2_t2) / (eff_t1_t1 * eff_t2_t1)) if all(v != np.nan for v in [eff_t1_t1, eff_t2_t1]) else np.nan
                    malmquist_index = EC * TC if EC is not np.nan and TC is not np.nan else np.nan
                    #print(malmquist_index)
                    effective_score_list.append(malmquist_index)
                else:
                    print("No feasible solution.")
                    effective_score_list.append(np.nan)
                    
        return effective_score_list

    def return_periods(self, year_):
        inputs_t1 = np.array(df[df['Year'] == year_][['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                            'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        outputs_t1 = np.array(df[df['Year'] == year_][['GHG_Intensity', 'ESG_Score']])
        inputs_t2 = np.array(df[df['Year'] == (year_+1)][['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                            'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        outputs_t2 = np.array(df[df['Year'] == (year_+1)][['GHG_Intensity', 'ESG_Score']])
        
        return inputs_t1, outputs_t1, inputs_t2, outputs_t2

    def Malquist_result(self):
        collection_slices = []
        for year_ in [2019, 2020, 2021, 2022]:
            in_t1, out_t1, in_t2, out_t2 = self.return_periods(year_)

            malmquist_indices = []
            EC_list = []
            TC_list = []
            for Dmu_index in range(self.num_dmus):
                """
                eff_t1_t1 = self.calculate_efficiency(in_t1, out_t1, in_t1, out_t1, Dmu_index)
                eff_t1_t2 = self.calculate_efficiency(in_t1, out_t1, in_t2, out_t2, Dmu_index)
                eff_t2_t1 = self.calculate_efficiency(in_t2, out_t2, in_t1, out_t1, Dmu_index)
                eff_t2_t2 = self.calculate_efficiency(in_t2, out_t2, in_t2, out_t2, Dmu_index)
                #print(eff_t1_t1, eff_t1_t2, eff_t2_t1, eff_t2_t2)
                """
                # Test another way to calculate the efficiency
                eff_t1_t1 = self.calculate_efficiency_from_concept(in_t1, out_t1, in_t1, out_t1, Dmu_index)
                eff_t1_t2 = self.calculate_efficiency_from_concept(in_t1, out_t1, in_t2, out_t2, Dmu_index)
                eff_t2_t1 = self.calculate_efficiency_from_concept(in_t2, out_t2, in_t1, out_t1, Dmu_index)
                eff_t2_t2 = self.calculate_efficiency_from_concept(in_t2, out_t2, in_t2, out_t2, Dmu_index)
                
                if all(v is not None for v in [eff_t1_t1, eff_t2_t2, eff_t1_t2, eff_t2_t1]):
                    # use string to alert no-optimal issue
                    EC = eff_t2_t2 / eff_t1_t1 if eff_t1_t1 != 0 else np.nan
                    TC = np.sqrt((eff_t1_t2 * eff_t2_t2) / (eff_t1_t1 * eff_t2_t1)) if all(v != 0 for v in [eff_t1_t1, eff_t2_t1]) else np.nan
                    #print(EC, TC)
                    EC_list.append(EC)
                    TC_list.append(TC)
                    malmquist_index = EC * TC if EC is not np.nan and TC is not np.nan else np.nan
                    malmquist_indices.append(malmquist_index)
                else:
                    malmquist_indices.append(None)

            malmquist_indices.extend(['ETC',f'{year_}_{year_+1}'])
            collection_slices.append(malmquist_indices)
            EC_list.extend(['EC',f'{year_}_{year_+1}'])
            TC_list.extend(['TC',f'{year_}_{year_+1}'])

            self.result_matrix.loc[len(self.result_matrix)] = malmquist_indices
            self.result_matrix.loc[len(self.result_matrix)] = EC_list
            self.result_matrix.loc[len(self.result_matrix)] = TC_list
    # input_oriented
    def SBM_model(self):
        SBM_IN = np.array(df[['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                            'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        SBM_OUT = np.array(df[['GHG_Intensity', 'ESG_Score']])
        n = len(SBM_IN)
        m = len(SBM_IN[0])
        s = len(SBM_OUT[0])

        # type in __init__
        # self.sbm_scores = []
        for DMU_NUM in range(n):
            prob = pulp.LpProblem("SBM_Model", pulp.LpMinimize)
            lambdas = [pulp.LpVariable(f"lambda_{k}", lowBound=0) for k in range(n)]
            s_minus = [pulp.LpVariable(f"s_minus_{i}", lowBound=0) for i in range(m)]
            #s_plus = [pulp.LpVariable(f"s_plus_{r}", lowBound=0) for r in range(s)]

            input_term = (1 / m) * sum([(s_minus[i]*(1.0/SBM_IN[DMU_NUM][i])) for i in range(m)])
            #output_term = (1 / s) * sum([(s_plus[r]*(1.0/SBM_OUT[DMU_NUM][r])) for r in range(s)])
            rho = 1-input_term
            prob += rho

            for i in range(m):
                prob += (pulp.lpSum([SBM_IN[k][i] * lambdas[k] for k in range(n)]) + s_minus[i] == SBM_IN[DMU_NUM][i])

            for r in range(s):
                prob += (pulp.lpSum([SBM_OUT[k][r] * lambdas[k] for k in range(n)]) >= SBM_OUT[DMU_NUM][r])
            
            prob.solve()

            if pulp.LpStatus[prob.status] == "Optimal":
                self.rho_list.append([DMU_NUM, pulp.value(rho)])
                for i in range(m):
                    print(f"s_minus_{i}:", pulp.value(s_minus[i]))
                    self.S_minus_list.append([DMU_NUM, pulp.value(s_minus[i])])
                """
                for r in range(s):
                    print(f"s_plus_{r}:", pulp.value(s_plus[r]))
                    self.S_plus_list.append(pulp.value(s_plus[r]))
                """
            else:
                self.rho_list.append([DMU_NUM, np.nan])
                print("No optimal solution found.")
        """
        for j, score in enumerate(self.rho_list):
            print(f"DMU {j+1} SBM Efficiency Score: {score}")
        """
        for i in self.rho_list:
            Company_name = df.iloc[i[0]]['Company']
            Year_ = df.iloc[i[0]]['Year']
            self.SBM_result.loc[len(self.SBM_result)] = [Company_name, Year_, i[1]]

# %%
Malquits_model = DEA_models()
Malquits_model.Malquist_result()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fc6d8704a43a46c9b3ae42de02c1d233-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fc6d8704a43a46c9b3ae42de02c1d233-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.135062 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c26b14c7261043b7bb3c70b9bd1e8d87-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c26b14c7261043b7bb3c70b9bd1e8d87-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.67202997 (2)
# 8  Obj 0.9913049
# Optimal - objective value 0.9913049
# Optimal objective 0.9913048986 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/17899354ee2f4e649a0dcfcaae19e6a3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/17899354ee2f4e649a0dcfcaae19e6a3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.4621574 (2)
# 8  Obj 2.3264703
# Optimal - objective value 2.3264703
# Optimal objective 2.326470278 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2afc72a71e5e49f9900f86d015d04270-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2afc72a71e5e49f9900f86d015d04270-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.60822091 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ffee55093b204398b8b92c2cc2541415-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ffee55093b204398b8b92c2cc2541415-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5639194 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7664ca9ca5884f108570002d80e0c7b4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7664ca9ca5884f108570002d80e0c7b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.28364612 (2)
# 5  Obj 1.003098
# Optimal - objective value 1.003098
# Optimal objective 1.003098023 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d5ec23a0c6844d70898a328816dbc7d6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d5ec23a0c6844d70898a328816dbc7d6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 108.2508 (2)
# 5  Obj 117.05747
# Optimal - objective value 117.05747
# Optimal objective 117.0574714 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d4ebaa8d076848c0994b50ac2e761e90-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d4ebaa8d076848c0994b50ac2e761e90-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.2505418 (2)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0f138ad6dc4343b7a2deca874612e2e2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0f138ad6dc4343b7a2deca874612e2e2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5032842 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0f9cd44e7a5049adb44ec5712756f2ab-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0f9cd44e7a5049adb44ec5712756f2ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.49310394 (2)
# 7  Obj 0.59054787
# Optimal - objective value 0.59054787
# Optimal objective 0.5905478719 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/16d408b0992140cb936b9b80d33c2c3f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/16d408b0992140cb936b9b80d33c2c3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.1367163 (2)
# 5  Obj 1.791208
# Optimal - objective value 1.791208
# Optimal objective 1.791208039 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2d8a9d7a84f845638fe359f40d48b840-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2d8a9d7a84f845638fe359f40d48b840-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.78086268 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/60a4ffea13474ceeb9023b4cbe606b6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/60a4ffea13474ceeb9023b4cbe606b6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.3250658 (2)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fe37717292a442a2a623abfe2b16301e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fe37717292a442a2a623abfe2b16301e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.83422457 (2)
# 9  Obj 1.1044558
# Optimal - objective value 1.1044558
# Optimal objective 1.104455831 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/84f76c9d32ce46ae8bf2f83dbbc39b4d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/84f76c9d32ce46ae8bf2f83dbbc39b4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.6796951 (2)
# 5  Obj 1.3546111
# Optimal - objective value 1.3546111
# Optimal objective 1.354611051 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/94dea9d9b6fb4f929c28a84b1516fb28-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/94dea9d9b6fb4f929c28a84b1516fb28-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0082225 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/00b80650c7ec42b9bd8cc7873c5da67c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/00b80650c7ec42b9bd8cc7873c5da67c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7780414 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/43f842b8c079474f844f477936304439-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/43f842b8c079474f844f477936304439-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.44331608 (2)
# 7  Obj 0.59543568
# Optimal - objective value 0.59543568
# Optimal objective 0.5954356815 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ef941024bc9b4164a332369429505ab6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ef941024bc9b4164a332369429505ab6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.779118 (2)
# 6  Obj 1.0617677
# Optimal - objective value 1.0617677
# Optimal objective 1.061767704 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5dccaece754a4e60be1d6dd27bcddae1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5dccaece754a4e60be1d6dd27bcddae1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.43238832 (2)
# 7  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f3ce3028b4b0489bb17abc8f246de4b5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f3ce3028b4b0489bb17abc8f246de4b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.60822091 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d1f85b61d5e04274bbf36a7c3e95c9bb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d1f85b61d5e04274bbf36a7c3e95c9bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.989497 (2)
# 6  Obj 0.96365609
# Optimal - objective value 0.96365609
# Optimal objective 0.9636560949 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e41d7a56a4284dc3be48d71238d4dbf5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e41d7a56a4284dc3be48d71238d4dbf5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.3510447 (2)
# 8  Obj 1.7891148
# Optimal - objective value 1.7891148
# Optimal objective 1.789114787 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/765226b3ad9041a4841294d21d02a8b4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/765226b3ad9041a4841294d21d02a8b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.2200898 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0f2f59eff13e4e2ba2098adcb0f4bee8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0f2f59eff13e4e2ba2098adcb0f4bee8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.2505418 (2)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/77feecb3fcc040fb93abf3d8a6407463-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/77feecb3fcc040fb93abf3d8a6407463-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 108.65447 (2)
# 5  Obj 88.689012
# Optimal - objective value 88.689012
# Optimal objective 88.68901244 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/439bf7d8abe24dee8c61887b4b0cadcc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/439bf7d8abe24dee8c61887b4b0cadcc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.21656618 (2)
# 4  Obj 0.84950063
# Optimal - objective value 0.84950063
# Optimal objective 0.8495006341 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/aa668a05f91149f994027d51a2b29487-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/aa668a05f91149f994027d51a2b29487-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5461645 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/803ebac495664d7f85d1650ef57c3170-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/803ebac495664d7f85d1650ef57c3170-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.78086268 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f974b0439e6641e6ad3ba5116691c316-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f974b0439e6641e6ad3ba5116691c316-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.0193275 (2)
# 8  Obj 0.98024867
# Optimal - objective value 0.98024867
# Optimal objective 0.9802486685 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/23a8fc25eb984b47a5b27c547ece5972-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/23a8fc25eb984b47a5b27c547ece5972-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.78687286 (2)
# 5  Obj 1.1510907
# Optimal - objective value 1.1510907
# Optimal objective 1.151090679 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/50008ef1bbf044f981105a200246d938-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/50008ef1bbf044f981105a200246d938-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.0437461 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/64d27ff26f3b434abfa51e5a9f225645-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/64d27ff26f3b434abfa51e5a9f225645-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0082225 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e5eb8032d30d479b97f1c216c69df604-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e5eb8032d30d479b97f1c216c69df604-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5267419 (2)
# 6  Obj 1.1320232
# Optimal - objective value 1.1320232
# Optimal objective 1.132023205 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ce25d70fc1f24b448282a65ffb9a5924-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ce25d70fc1f24b448282a65ffb9a5924-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0505564 (2)
# 5  Obj 1.1534585
# Optimal - objective value 1.1534585
# Optimal objective 1.153458454 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/74789292b53e4a4e97a2a71a0c1a5892-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/74789292b53e4a4e97a2a71a0c1a5892-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.7126877 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a885d76ac4964c0f8614a26e2e9024fa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a885d76ac4964c0f8614a26e2e9024fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.43238832 (2)
# 7  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a271353409264782b317d53a0ff9903c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a271353409264782b317d53a0ff9903c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7450756 (2)
# 5  Obj 0.94187454
# Optimal - objective value 0.94187454
# Optimal objective 0.9418745398 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8258058ea36c4cb08e53f7a65873116b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8258058ea36c4cb08e53f7a65873116b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7257832 (2)
# 5  Obj 2.5576029
# Optimal - objective value 2.5576029
# Optimal objective 2.557602946 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7c003c41954642aaad35e7fdb36e5935-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7c003c41954642aaad35e7fdb36e5935-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 3.8799179 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/59bde6a2ff4c4e2a87ea061d2f996f81-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/59bde6a2ff4c4e2a87ea061d2f996f81-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.2200898 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a4e56e4b60764c7e96f4bdad07819fe2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a4e56e4b60764c7e96f4bdad07819fe2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5467721 (2)
# 7  Obj 2.0214569
# Optimal - objective value 2.0214569
# Optimal objective 2.021456898 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/04859ed317834b2196adf22e5dfc4ae5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/04859ed317834b2196adf22e5dfc4ae5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5119611 (2)
# 7  Obj 2.0241449
# Optimal - objective value 2.0241449
# Optimal objective 2.024144869 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ed7f19c35e1b4c30863de57e9980bfa3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ed7f19c35e1b4c30863de57e9980bfa3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.4150417 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d820d6103c67421a9fb7318b97c09e0a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d820d6103c67421a9fb7318b97c09e0a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5461645 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/428ab61eae034a3a929bfca3f007570d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/428ab61eae034a3a929bfca3f007570d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.6563287 (2)
# 7  Obj 0.94432424
# Optimal - objective value 0.94432424
# Optimal objective 0.9443242424 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f664529782a7470eb1ed3c01f95e2b4d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f664529782a7470eb1ed3c01f95e2b4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.624034 (2)
# 7  Obj 1.8951957
# Optimal - objective value 1.8951957
# Optimal objective 1.895195713 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b19a7f83e7f3491486f8bb9c9c00d881-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b19a7f83e7f3491486f8bb9c9c00d881-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5974745 (2)
# 4  Obj 1
# ...
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/26724a2ba27d4ddc8c686d99d40108d5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/26724a2ba27d4ddc8c686d99d40108d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5974745 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/25053b7e8aed4b72a79e625ea1a1349f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/25053b7e8aed4b72a79e625ea1a1349f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.3076607 (2)
# 9  Obj 2.4754695
# Optimal - objective value 2.4754695
# Optimal objective 2.475469488 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/06b3cac5b9d9426694f6f279d0f39b0a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/06b3cac5b9d9426694f6f279d0f39b0a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.4171166 (2)
# 7  Obj 0.88853885
# Optimal - objective value 0.88853885
# Optimal objective 0.8885388547 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e2e77600c565429ca32c0b6ada5c0c3f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e2e77600c565429ca32c0b6ada5c0c3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0981443 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e5183935db5b458cb2b4691f22b1c279-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e5183935db5b458cb2b4691f22b1c279-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5296269 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/90aaa81f2230461bbbe51b0c3176757a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/90aaa81f2230461bbbe51b0c3176757a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.4587779 (2)
# 5  Obj 0.90708826
# Optimal - objective value 0.90708826
# Optimal objective 0.9070882626 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ae5c6e6b4552426b99b4ff2fc4c93c54-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ae5c6e6b4552426b99b4ff2fc4c93c54-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.8504452 (2)
# 9  Obj 1.5981008
# Optimal - objective value 1.5981008
# Optimal objective 1.59810083 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a6b8134a6c6540a29ad9396384877e16-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a6b8134a6c6540a29ad9396384877e16-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.6970717 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6127fde1b80e4bd9a5cb1aeacd96fc66-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6127fde1b80e4bd9a5cb1aeacd96fc66-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.8980217 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b6e8d480979d4f4f9cd5299fb5263c74-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b6e8d480979d4f4f9cd5299fb5263c74-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7152594 (2)
# 5  Obj 0.96966601
# Optimal - objective value 0.96966601
# Optimal objective 0.9696660131 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4e0628063bcd4755a10c908442160944-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4e0628063bcd4755a10c908442160944-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 3.3128838 (2)
# 7  Obj 1.1042885
# Optimal - objective value 1.1042885
# Optimal objective 1.104288498 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a58f8838eada49ab88b248a21eae86e2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a58f8838eada49ab88b248a21eae86e2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.9154262 (2)
# 5  Obj 0.99328206
# Optimal - objective value 0.99328206
# Optimal objective 0.9932820586 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b2a96993106d42d48dc17f2f94c06716-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b2a96993106d42d48dc17f2f94c06716-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 4.3748772 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/db381bdac3a44407ae069885cc54ac56-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/db381bdac3a44407ae069885cc54ac56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.4446539 (2)
# 6  Obj 1.0597712
# Optimal - objective value 1.0597712
# Optimal objective 1.059771185 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fe940b3a9ad54f9daa0934c0fb07b461-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fe940b3a9ad54f9daa0934c0fb07b461-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 4.5734812 (2)
# 9  Obj 1.3948792
# Optimal - objective value 1.3948792
# Optimal objective 1.39487918 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/362e9410cf3341f09feebf8da241fc85-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/362e9410cf3341f09feebf8da241fc85-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.654541 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
Malquits_model.Malquist_concepted_model
# Out:
# [Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.76 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 98.1 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 13.568 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 4.6 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 263.1
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.51
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.76 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 98.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 13.568 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 4.6 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 263.1
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.51
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 237.57
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 237.57
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.53 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 15.9 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 21.19 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 43.8 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 108.54
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 5.14
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.53 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 15.9 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 21.19 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 43.8 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 108.54
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 5.14
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 99.39
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 99.39
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 16.31 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 72.5 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 31.66 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 13.125 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 193.29
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 3
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 16.31 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 72.5 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 31.66 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 13.125 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 193.29
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 307.01
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 307.01
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.9 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 62.9 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 67.97 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 7.175 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 327.83
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.01
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.9 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 62.9 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 67.97 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 7.175 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 327.83
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.01
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 396.7
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 396.7
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 155.4 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 88.1 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 1149.34 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 5 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 172.16
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 155.4 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 88.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1149.34 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 172.16
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 5 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 167.67
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 167.67
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 237.57
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 237.57
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 283.36
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 283.36
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 99.39
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 99.39
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 81.48
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 81.48
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 307.01
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 307.01
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 309.34
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 309.34
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 396.7
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 396.7
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 413.06
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 413.06
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 167.67
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 167.67
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 156.48 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 83.7 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1247.14 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 4.2 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 680.69
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 5.07
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 156.48 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 83.7 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 1247.14 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 4.2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 680.69
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.07
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 283.36
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 283.36
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 95 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 95.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 3.392 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 255.6
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.03
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 95 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 95.1 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 3.392 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 255.6
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.03
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 81.48
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 81.48
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 61.92
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 61.92
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 309.34
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 309.34
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 337.1
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 337.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 413.06
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 413.06
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 20 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 361.1
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 20 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 361.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 156.48 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 83.7 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
# ...
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 95.1 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 3.392 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 2 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 255.6
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.03
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 96.22 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 89.9 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 0.01 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 3.3 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 283.35
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.09
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 96.22 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 89.9 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 0.01 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 3.3 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 283.35
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.09
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 61.92
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 61.92
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 11.68 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 16.8 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 16.96 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 44.7 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 44.65
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.66
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 11.68 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 16.8 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 16.96 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 44.7 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 44.65
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.66
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 337.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 337.1
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.62 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 49.7 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 16.88 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 9.6 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 349.49
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.62 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 49.7 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 16.88 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 9.6 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 349.49
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 20 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 361.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 20 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 361.1
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 20.18 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 62.45 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 40.97 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 13.7 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 438.65
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 20.18 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 62.45 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 40.97 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 13.7 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 438.65
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 157.98 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 75.3 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 1299.72 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 3.5 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 627.58
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.13
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 157.98 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 75.3 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 1299.72 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 3.5 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 627.58
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.13
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 198.52 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 74.5 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 1637.59 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 2.9 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 725.33
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.95
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 198.52 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 74.5 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 1637.59 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 2.9 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 725.33
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.95
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous]

# %%
for model_ in Malquits_model.Malquist_concepted_model:
    print(pulp.LpStatus[model_.status])
# Out:
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal

# %%
for v in Malquits_model.Malquist_concepted_model[8].variables():
    print(f"{v.name} = {v.varValue}")
# Out:
# Theta = 1.0
# lambda_0 = 0.0
# lambda_1 = 0.0
# lambda_2 = 1.0
# lambda_3 = 0.0
# lambda_4 = 0.0

# %%
#Malquits_model.result_matrix.to_csv("Malquist_Index.csv")
Malquits_model.result_matrix
# Out:
#         SONY       APPL      DELL       HPE   SAMSUNG EorT     Period
# 0   0.652762   0.092570  0.574189  0.902957  0.338977  ETC  2019_2020
# 1   1.000000   1.000000  1.000000  1.000000  0.589538   EC  2019_2020
# 2   0.652762   0.092570  0.574189  0.902957  0.574988   TC  2019_2020
# 3   0.733909  10.217698  0.922812  0.990665  1.340639  ETC  2020_2021
# 4   1.000000   1.000000  1.000000  1.000000  1.696242   EC  2020_2021
# 5   0.733909  10.217698  0.922812  0.990665  0.790358   TC  2020_2021
# 6   0.999336   0.705884  0.855162  1.089352  0.967881  ETC  2021_2022
# 7   1.000000   1.000000  1.000000  1.000000  1.000000   EC  2021_2022
# 8   0.999336   0.705884  0.855162  1.089352  0.967881   TC  2021_2022
# 9   0.065840   1.669132  0.753395  0.927638  0.871641  ETC  2022_2023
# 10  1.000000   1.000000  1.000000  0.993282  1.000000   EC  2022_2023
# 11  0.065840   1.669132  0.753395  0.933912  0.871641   TC  2022_2023

# %%
Malquits_model.SBM_model()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/458925b957dd43549ecfd53aed7d081f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/458925b957dd43549ecfd53aed7d081f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 3047.8908 - largest nonzero change 3.0212823e-05 ( 0.00057190936%) - largest zero change 2.8195717e-05
# 0  Obj 0 Primal inf 5.7942556 (6) Dual inf 3067.5753 (4)
# 0  Obj 0 Primal inf 5.7942556 (6) Dual inf 1.5519834e+13 (29)
# 5  Obj -5.3646363e-09
# Optimal - objective value -5.3646363e-09
# Optimal objective -5.364636314e-09 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 0.0
# s_minus_1: 1.7806384e-09
# s_minus_2: 2.1432967e-10
# s_minus_3: 1.9044239e-11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a0331b4735434b4c8778f01269996b67-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a0331b4735434b4c8778f01269996b67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 17.060296 - largest nonzero change 1.8890932e-06 ( 1.4382056e-05%) - largest zero change 1.8529971e-06
# 0  Obj 0 Primal inf 6.3032919 (6) Dual inf 35.176504 (4)
# 0  Obj 0 Primal inf 6.3032919 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -7.9144372e-12
# Optimal - objective value -7.9144372e-12
# Optimal objective -7.914437194e-12 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 3.5665003e-09
# s_minus_1: 1.1753652e-09
# s_minus_2: 0.0
# s_minus_3: -3.6487232e-11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f341d60c8544440081f584dbe15be496-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f341d60c8544440081f584dbe15be496-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 17.060296 - largest nonzero change 1.8890932e-06 ( 1.4343277e-05%) - largest zero change 1.8529971e-06
# 0  Obj 0 Primal inf 6.2751398 (6) Dual inf 36.642232 (4)
# 0  Obj 0 Primal inf 6.2751398 (6) Dual inf 1.5519834e+13 (29)
# 5  Obj -1.8862947e-11
# Optimal - objective value -1.8862947e-11
# Optimal objective -1.886294652e-11 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 7.686595e-10
# s_minus_1: 1.7806676e-09
# s_minus_2: 1.2796688e-10
# s_minus_3: 3.7725859e-11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/48e9770a741144f385c9f8b71a876ac8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/48e9770a741144f385c9f8b71a876ac8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 16.247901 - largest nonzero change 1.8036874e-06 ( 1.4516009e-05%) - largest zero change 1.7973671e-06
# 0  Obj 0 Primal inf 6.9700505 (6) Dual inf 34.299097 (4)
# 0  Obj 0 Primal inf 6.9700505 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.23810183
# Optimal - objective value -0.23810183
# Optimal objective -0.238101829 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 6.4474939
# s_minus_1: 16.677321
# s_minus_2: 4.4669602
# s_minus_3: 0.3792311
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e28ec791e101427d9168f81893c7e0ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e28ec791e101427d9168f81893c7e0ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 10.370896 - largest nonzero change 9.0358923e-07 ( 1.4751907e-05%) - largest zero change 8.688408e-07
# 0  Obj 0 Primal inf 8.5394272 (6) Dual inf 24.57267 (4)
# 0  Obj 0 Primal inf 8.5394272 (6) Dual inf 1.5519834e+13 (29)
# 6  Obj -0.32757489
# Optimal - objective value -0.32757489
# Optimal objective -0.3275748922 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 2.9235905
# s_minus_1: 10.44952
# s_minus_2: 7.2690503
# s_minus_3: 2.7429983
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e34c33a59c724002848f30520819ad1c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e34c33a59c724002848f30520819ad1c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 36.191587 - largest nonzero change 2.835893e-06 ( 6.7390872e-05%) - largest zero change 2.6619756e-06
# 0  Obj 0 Primal inf 15.74522 (6) Dual inf 65.249956 (4)
# 0  Obj 0 Primal inf 15.74522 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -0.83172167
# Optimal - objective value -0.83172167
# Optimal objective -0.8317216712 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 10.231454
# s_minus_1: 10.44584
# s_minus_2: 14.654836
# s_minus_3: 43.137626
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2cb8f08c522b43b1b493f59219da7ad0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2cb8f08c522b43b1b493f59219da7ad0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 57.813702 - largest nonzero change 5.8869459e-06 ( 7.9646913e-05%) - largest zero change 5.7846557e-06
# 0  Obj 0 Primal inf 13.594853 (6) Dual inf 104.36963 (4)
# 0  Obj 0 Primal inf 13.594853 (6) Dual inf 1.5519834e+13 (29)
# 11  Obj -5.2698361e-11
# Optimal - objective value -5.2698361e-11
# Optimal objective -5.269836136e-11 - 11 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.9235223e-10
# s_minus_1: -4.5989836e-11
# s_minus_2: 8.8129122e-10
# s_minus_3: 3.6930382e-09
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9f520ce5edac425ba89fba722e102e62-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9f520ce5edac425ba89fba722e102e62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 38.924285 - largest nonzero change 3.3232294e-06 ( 5.9575351e-05%) - largest zero change 3.2987491e-06
# 0  Obj 0 Primal inf 14.089699 (6) Dual inf 73.182771 (4)
# 0  Obj 0 Primal inf 14.089699 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -0.65963888
# Optimal - objective value -0.65963888
# Optimal objective -0.6596388805 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 8.3003592
# s_minus_1: 2.5087528
# s_minus_2: 13.329046
# s_minus_3: 33.955476
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8612e0850ee946d884c469ad1b91108d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8612e0850ee946d884c469ad1b91108d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 34.367295 - largest nonzero change 3.1831593e-06 ( 5.5165012e-05%) - largest zero change 3.0381216e-06
# 0  Obj 0 Primal inf 58.940636 (6) Dual inf 67.324803 (4)
# 0  Obj 0 Primal inf 58.940636 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -6.7141077e-11
# Optimal - objective value -6.7141077e-11
# Optimal objective -6.714107684e-11 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 1.1503697e-09
# s_minus_1: 2.4050682e-09
# s_minus_2: 1.3065625e-10
# s_minus_3: 1.3647988e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/617f18e885cb46968a6ab13e7b540303-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/617f18e885cb46968a6ab13e7b540303-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 33.736451 - largest nonzero change 2.9502115e-06 ( 6.3214396e-05%) - largest zero change 2.9489563e-06
# 0  Obj 0 Primal inf 16.857099 (6) Dual inf 63.951647 (4)
# 0  Obj 0 Primal inf 16.857099 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.6086
# Optimal - objective value -0.6086
# Optimal objective -0.6086000007 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 9.1653494
# s_minus_1: 0.46149265
# s_minus_2: 15.840041
# s_minus_3: 40.57538
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/465850c214394464a20899dc8bef06ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/465850c214394464a20899dc8bef06ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 39.80393 - largest nonzero change 3.0659512e-06 ( 2.9075269e-05%) - largest zero change 2.8701513e-06
# 0  Obj 0 Primal inf 9.5290537 (6) Dual inf 54.120827 (4)
# 0  Obj 0 Primal inf 9.5290537 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -2.5585134e-10
# Optimal - objective value -2.5585134e-10
# Optimal objective -2.558513376e-10 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 8.4943294e-09
# s_minus_1: 1.3710375e-08
# s_minus_2: -1.1228056e-09
# s_minus_3: 1.3648228e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d42f844cec3c43a5b333983df16bab1f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d42f844cec3c43a5b333983df16bab1f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 34.228156 - largest nonzero change 2.6460598e-06 ( 3.0918582e-05%) - largest zero change 2.548825e-06
# 0  Obj 0 Primal inf 10.832233 (6) Dual inf 47.128327 (4)
# 0  Obj 0 Primal inf 10.832233 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.1654859
# Optimal - objective value -0.1654859
# Optimal objective -0.1654858963 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 2.1064966
# s_minus_1: 4.8619474
# s_minus_2: 4.368424
# s_minus_3: 2.1403359
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/60a9f7dd940c43fb8674f6f87cddf46f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/60a9f7dd940c43fb8674f6f87cddf46f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 29.274081 - largest nonzero change 2.2729862e-06 ( 3.3236512e-05%) - largest zero change 2.2633266e-06
# 0  Obj 0 Primal inf 12.154514 (6) Dual inf 41.651341 (4)
# 0  Obj 0 Primal inf 12.154514 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.30789736
# Optimal - objective value -0.30789736
# Optimal objective -0.3078973646 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.0400435
# s_minus_1: 9.4096197
# s_minus_2: 10.639203
# s_minus_3: 3.4778642
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ea726606bb7b431c9411820673632b53-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ea726606bb7b431c9411820673632b53-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 28.913662 - largest nonzero change 2.2458443e-06 ( 3.5817529e-05%) - largest zero change 2.2425559e-06
# 0  Obj 0 Primal inf 13.148624 (6) Dual inf 39.907823 (4)
# 0  Obj 0 Primal inf 13.148624 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.36547506
# Optimal - objective value -0.36547506
# Optimal objective -0.365475064 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.2908455
# s_minus_1: 18.140963
# s_minus_2: 13.601739
# s_minus_3: 4.116866
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/cdefa559a365455d88a4ae5407d36105-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/cdefa559a365455d88a4ae5407d36105-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 25.917703 - largest nonzero change 2.0202294e-06 ( 3.6600305e-05%) - largest zero change 2.0120712e-06
# 0  Obj 0 Primal inf 13.775116 (6) Dual inf 35.620271 (4)
# 0  Obj 0 Primal inf 13.775116 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.63970213
# Optimal - objective value -0.63970213
# Optimal objective -0.6397021314 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 10.429994
# s_minus_1: 45.012442
# s_minus_2: 22.313807
# s_minus_3: 7.7918884
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/826ad573b28d471baff0e0df5a2b4dbd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/826ad573b28d471baff0e0df5a2b4dbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 20.94736 - largest nonzero change 1.6459308e-06 ( 3.9919308e-05%) - largest zero change 1.6397317e-06
# 0  Obj 0 Primal inf 17.416347 (6) Dual inf 31.310194 (4)
# 0  Obj 0 Primal inf 17.416347 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.2359995
# Optimal - objective value -0.2359995
# Optimal objective -0.235999505 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 6.850683
# s_minus_1: 0.070804601
# s_minus_2: 19.783666
# s_minus_3: 1.6508999
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d39bb0bef80c4ffcbb2005ae322163b9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d39bb0bef80c4ffcbb2005ae322163b9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 17.576621 - largest nonzero change 1.3920925e-06 ( 4.2153717e-05%) - largest zero change 1.3786931e-06
# 0  Obj 0 Primal inf 20.501817 (6) Dual inf 28.39804 (4)
# 0  Obj 0 Primal inf 20.501817 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.42828018
# Optimal - objective value -0.42828018
# Optimal objective -0.4282801816 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 13.077205
# s_minus_1: 1.0489742
# s_minus_2: 31.729249
# s_minus_3: 10.08109
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e4e88e79be1c417ea16d36a70e6e8260-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e4e88e79be1c417ea16d36a70e6e8260-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 15.360383 - largest nonzero change 1.2251956e-06 ( 4.0630078e-05%) - largest zero change 1.2150818e-06
# 0  Obj 0 Primal inf 20.345638 (6) Dual inf 26.355234 (4)
# 0  Obj 0 Primal inf 20.345638 (6) Dual inf 1.5519834e+13 (29)
# 10  Obj -1.2735316e-09
# Optimal - objective value -1.2735316e-09
# Optimal objective -1.273531581e-09 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.9346954e-08
# s_minus_1: 0.0
# s_minus_2: 1.0233587e-07
# s_minus_3: 1.470232e-08
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/563f8295bda24c89ae65827d1d539307-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/563f8295bda24c89ae65827d1d539307-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 15.124069 - largest nonzero change 1.2073996e-06 ( 4.4806701e-05%) - largest zero change 1.2037594e-06
# 0  Obj 0 Primal inf 21.12922 (6) Dual inf 26.25105 (4)
# 0  Obj 0 Primal inf 21.12922 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.33035715
# Optimal - objective value -0.33035715
# Optimal objective -0.3303571452 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 15.895423
# s_minus_1: 1.9863973
# s_minus_2: 38.969807
# s_minus_3: 0.55320753
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/80a378cc5eab4fd7abf0fbf609351ac1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/80a378cc5eab4fd7abf0fbf609351ac1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 15.151173 - largest nonzero change 1.2094407e-06 ( 5.1128575e-05%) - largest zero change 1.205058e-06
# 0  Obj 0 Primal inf 22.426207 (6) Dual inf 27.432423 (4)
# 0  Obj 0 Primal inf 22.426207 (6) Dual inf 1.5519834e+13 (29)
# 6  Obj -0.2410394
# Optimal - objective value -0.2410394
# Optimal objective -0.2410394009 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 7.4567333
# s_minus_1: 0.0
# s_minus_2: 47.367693
# s_minus_3: 0.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/eb113c3c20a349459bbb3121fda25582-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/eb113c3c20a349459bbb3121fda25582-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 11.765721 - largest nonzero change 1.332483e-06 ( 0.00091245738%) - largest zero change 1.254337e-06
# 0  Obj 0 Primal inf 427.98192 (6) Dual inf 19.889052 (4)
# 0  Obj 0 Primal inf 427.98192 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -8.4071e-12
# Optimal - objective value -8.4071e-12
# Optimal objective -8.407100023e-12 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: -1.3343428e-09
# s_minus_1: 0.0
# s_minus_2: -1.1024951e-08
# s_minus_3: 1.365386e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3be975b5ad14479d92bfd4874f34bd52-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3be975b5ad14479d92bfd4874f34bd52-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 9.7487404 - largest nonzero change 1.120441e-06 ( 0.0006592532%) - largest zero change 1.1063032e-06
# 0  Obj 0 Primal inf 340.57758 (6) Dual inf 18.359848 (4)
# 0  Obj 0 Primal inf 340.57758 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -0.036794498
# Optimal - objective value -0.036794498
# Optimal objective -0.03679449782 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 0.0
# s_minus_1: 4.4707101
# s_minus_2: 16.804545
# s_minus_3: 0.26206829
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c9441b156a254292ab178b0da2dd9650-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c9441b156a254292ab178b0da2dd9650-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 8.1239504 - largest nonzero change 9.4962935e-07 ( 0.00058146233%) - largest zero change 9.4248045e-07
# 0  Obj 0 Primal inf 327.64067 (6) Dual inf 16.168388 (4)
# 0  Obj 0 Primal inf 327.64067 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -9.7330098e-12
# Optimal - objective value -9.8032914e-12
# Optimal objective -9.803291436e-12 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 4.3990665e-11
# s_minus_1: 5.3869449e-10
# s_minus_2: 0.0
# s_minus_3: 1.364833e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/caa2cd91a6f64b2b929799be5506b834-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/caa2cd91a6f64b2b929799be5506b834-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 6.8241183 - largest nonzero change 8.1298006e-07 ( 0.00052120094%) - largest zero change 8.0608717e-07
# 0  Obj 0 Primal inf 314.30707 (6) Dual inf 14.585609 (4)
# 0  Obj 0 Primal inf 314.30707 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.75490742
# Optimal - objective value -0.75490742
# Optimal objective -0.7549074221 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 118.97117
# s_minus_1: 68.845358
# s_minus_2: 825.36313
# s_minus_3: 4.0572968
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d9f156b784e04f42a073a3c0a3e87e58-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d9f156b784e04f42a073a3c0a3e87e58-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 6.8241183 - largest nonzero change 8.1298006e-07 ( 0.00049855073%) - largest zero change 8.0608717e-07
# 0  Obj 0 Primal inf 300.60971 (6) Dual inf 14.623783 (4)
# 0  Obj 0 Primal inf 300.60971 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.74265283
# Optimal - objective value -0.74265283
# Optimal objective -0.7426528252 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 108.38555
# s_minus_1: 70.386162
# s_minus_2: 762.0937
# s_minus_3: 4.05572

# %%
#Malquits_model.SBM_result.to_csv('SBM_result.csv')

# %%
Malquits_model.SBM_result
# Out:
#               Conpany  Year       Rho
# 0      SONY US Equity  2023  1.000000
# 1      SONY US Equity  2022  1.000000
# 2      SONY US Equity  2021  1.000000
# 3      SONY US Equity  2020  0.761898
# 4      SONY US Equity  2019  0.672425
# 5      AAPl US Equity  2023  0.168278
# 6      AAPl US Equity  2022  1.000000
# 7      AAPl US Equity  2021  0.340361
# 8      AAPl US Equity  2020  1.000000
# 9      AAPl US Equity  2019  0.391400
# 10     DELL US Equity  2023  1.000000
# 11     DELL US Equity  2022  0.834514
# 12     DELL US Equity  2021  0.692103
# 13     DELL US Equity  2020  0.634525
# 14     DELL US Equity  2019  0.360298
# 15      HPE US Equity  2023  0.764000
# 16      HPE US Equity  2022  0.571720
# 17      HPE US Equity  2021  1.000000
# 18      HPE US Equity  2020  0.669643
# 19      HPE US Equity  2019  0.758961
# 20  SAMSUNG KS Equity  2023  1.000000
# 21  SAMSUNG KS Equity  2022  0.963206
# 22  SAMSUNG KS Equity  2021  1.000000
# 23  SAMSUNG KS Equity  2020  0.245093
# 24  SAMSUNG KS Equity  2019  0.257347

# %%
effective_score_list = Malquits_model.Primal_equation_test()
len(effective_score_list)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5248aab0068c46e4ad28909bab1dac62-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5248aab0068c46e4ad28909bab1dac62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.057216362 (1) Dual inf 165.77645 (2)
# 0  Obj -0 Primal inf 0.057216362 (1) Dual inf 1.0507489e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f2c7a3a41b034cd99592006fbd3b1836-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f2c7a3a41b034cd99592006fbd3b1836-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.057672438 (1) Dual inf 133.9328 (2)
# 0  Obj -0 Primal inf 0.057672438 (1) Dual inf 9.2015466e+10 (6)
# 8  Obj 0.99780745
# Optimal - objective value 0.99780745
# Optimal objective 0.9978074476 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/618403749d504813925a9be8eac80578-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/618403749d504813925a9be8eac80578-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0487978 (1) Dual inf 163.05246 (2)
# 0  Obj -0 Primal inf 0.0487978 (1) Dual inf 1.7686629e+11 (6)
# 4  Obj 2.3771267
# Optimal - objective value 2.3771267
# Optimal objective 2.377126743 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3c66030762ed424696cafd71b7771c4b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3c66030762ed424696cafd71b7771c4b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 149.23711 (2)
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 1.7791917e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/20fab082e7dc4f1aad9e43e1335b9370-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/20fab082e7dc4f1aad9e43e1335b9370-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030751319 (1) Dual inf 140.95707 (2)
# 0  Obj -0 Primal inf 0.030751319 (1) Dual inf 6.194043e+10 (6)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/280edaa7eca94815a0105b290dd72fc7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/280edaa7eca94815a0105b290dd72fc7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.031486454 (1) Dual inf 8249.7669 (2)
# 0  Obj -0 Primal inf 0.031486454 (1) Dual inf 6.025081e+10 (6)
# 9  Obj 97.782443
# Optimal - objective value 97.782443
# Optimal objective 97.78244276 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/58236d8f603e414faa3af954c33670df-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/58236d8f603e414faa3af954c33670df-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030508059 (1) Dual inf 72.321724 (2)
# 0  Obj -0 Primal inf 0.030508059 (1) Dual inf 1.1481647e+11 (6)
# 4  Obj 1.1788354
# Optimal - objective value 1.1788354
# Optimal objective 1.178835377 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4eb03742d14b4559b4d4dd2dbc90b65d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4eb03742d14b4559b4d4dd2dbc90b65d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 853.89448 (2)
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 1.1519667e+11 (6)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7ea539bc28684f618ab219c4ae5a1a4d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7ea539bc28684f618ab219c4ae5a1a4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.039150934 (1) Dual inf 127.11953 (2)
# 0  Obj -0 Primal inf 0.039150934 (1) Dual inf 6.2432398e+10 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/44534f709b9d4e138f744ba666fe0d7c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/44534f709b9d4e138f744ba666fe0d7c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.042566796 (1) Dual inf 138.44706 (2)
# 0  Obj -0 Primal inf 0.042566796 (1) Dual inf 6.0011309e+10 (6)
# 7  Obj 1.4478116
# Optimal - objective value 1.4478116
# Optimal objective 1.447811586 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4ec8c1cb0c2345e8bc713cdf7c4e9450-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4ec8c1cb0c2345e8bc713cdf7c4e9450-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.029593314 (1) Dual inf 119.30567 (2)
# 0  Obj -0 Primal inf 0.029593314 (1) Dual inf 1.2321648e+11 (6)
# 6  Obj 0.72579895
# Optimal - objective value 0.72579895
# Optimal objective 0.7257989489 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/af360bedf134460aa1ac54ba41773fae-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/af360bedf134460aa1ac54ba41773fae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 188.77643 (2)
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 1.2217145e+11 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1ee6050324bc438fa34b5c432634a1b4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1ee6050324bc438fa34b5c432634a1b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.033401665 (1) Dual inf 193.89261 (2)
# 0  Obj -0 Primal inf 0.033401665 (1) Dual inf 5.6012452e+10 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/08f260ff038249a79fb624ba67d4ee61-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/08f260ff038249a79fb624ba67d4ee61-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.033553404 (1) Dual inf 172.77279 (2)
# 0  Obj -0 Primal inf 0.033553404 (1) Dual inf 4.8260165e+10 (6)
# 4  Obj 1.4978998
# Optimal - objective value 1.4978998
# Optimal objective 1.497899761 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/71b31a82dd434cc493266da6a2772bdc-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/71b31a82dd434cc493266da6a2772bdc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.021289679 (1) Dual inf 200.68659 (2)
# 0  Obj -0 Primal inf 0.021289679 (1) Dual inf 9.6880747e+10 (6)
# 5  Obj 0.93057634
# Optimal - objective value 0.93057634
# Optimal objective 0.9305763427 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b8c2652ca6f245949708a903dd95a5bf-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b8c2652ca6f245949708a903dd95a5bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 243.32037 (2)
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 9.8546244e+10 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/78fa6b7f326442549ea8692f8b86398c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/78fa6b7f326442549ea8692f8b86398c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.01226369 (1) Dual inf 155.66695 (2)
# 0  Obj -0 Primal inf 0.01226369 (1) Dual inf 1.012905e+11 (6)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/39b727429eb0414e81a31b64fe004cbe-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/39b727429eb0414e81a31b64fe004cbe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.012081527 (1) Dual inf 123.24868 (2)
# 0  Obj -0 Primal inf 0.012081527 (1) Dual inf 8.8018169e+10 (6)
# 6  Obj 1.0286174
# Optimal - objective value 1.0286174
# Optimal objective 1.028617368 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a33da727ce9947808a5957a724c168bb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a33da727ce9947808a5957a724c168bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0079539833 (1) Dual inf 109.47534 (2)
# 0  Obj -0 Primal inf 0.0079539833 (1) Dual inf 1.1917171e+11 (6)
# 5  Obj 0.67131124
# Optimal - objective value 0.67131124
# Optimal objective 0.6713112437 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/57db1a76a7384e5c868e83ba1565f124-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/57db1a76a7384e5c868e83ba1565f124-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 107.80925 (2)
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 1.1173613e+11 (6)
# 6  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/80fb053c2e214eeba58097e511c324aa-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/80fb053c2e214eeba58097e511c324aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 149.23711 (2)
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 1.7791917e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e4fb37b528234e1c8c72c2a0a1e35bac-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e4fb37b528234e1c8c72c2a0a1e35bac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.04821381 (1) Dual inf 174.32615 (2)
# 0  Obj -0 Primal inf 0.04821381 (1) Dual inf 1.6855404e+11 (6)
# 5  Obj 1.1862643
# Optimal - objective value 1.1862643
# Optimal objective 1.186264271 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e5b9bd42a0e74caea09b769261c01c41-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e5b9bd42a0e74caea09b769261c01c41-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.092523959 (1) Dual inf 114.42676 (2)
# 0  Obj -0 Primal inf 0.092523959 (1) Dual inf 1.0390777e+11 (6)
# 8  Obj 1.445674
# Optimal - objective value 1.445674
# Optimal objective 1.445674044 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3c925de821c74d6d9b3a43d5e4ba055f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3c925de821c74d6d9b3a43d5e4ba055f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 121.62492 (2)
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 1.1303689e+11 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1c7312845e9f47438ee5dedf0034d690-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1c7312845e9f47438ee5dedf0034d690-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 853.89448 (2)
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 1.1519667e+11 (6)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/61f2dc95b4254ba88cfe05b8b93c6805-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/61f2dc95b4254ba88cfe05b8b93c6805-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.029535824 (1) Dual inf 56.369941 (2)
# 0  Obj -0 Primal inf 0.029535824 (1) Dual inf 1.1796245e+11 (6)
# 5  Obj 0.76144028
# Optimal - objective value 0.76144028
# Optimal objective 0.7614402777 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/797dca6294af46fd9cf1ee0dbbbcd190-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/797dca6294af46fd9cf1ee0dbbbcd190-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.037107372 (1) Dual inf 7512.8098 (2)
# 0  Obj -0 Primal inf 0.037107372 (1) Dual inf 6.068362e+10 (6)
# 10  Obj 101.93006
# Optimal - objective value 101.93006
# Optimal objective 101.9300558 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/10a0850bee474f3e842849c69632ca12-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/10a0850bee474f3e842849c69632ca12-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.033735405 (1) Dual inf 103.69567 (2)
# 0  Obj -0 Primal inf 0.033735405 (1) Dual inf 6.6063808e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/784f36861f3e46159448239c35b64ce6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/784f36861f3e46159448239c35b64ce6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 188.77643 (2)
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 1.2217145e+11 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6f4cacddad7840aab6fb75e305df0b35-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6f4cacddad7840aab6fb75e305df0b35-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030776829 (1) Dual inf 187.6969 (2)
# 0  Obj -0 Primal inf 0.030776829 (1) Dual inf 1.1477728e+11 (6)
# 5  Obj 0.99521959
# Optimal - objective value 0.99521959
# Optimal objective 0.9952195851 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b606f275cfd34c9f8d20a67f96af54c9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b606f275cfd34c9f8d20a67f96af54c9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.052431987 (1) Dual inf 127.82032 (2)
# 0  Obj -0 Primal inf 0.052431987 (1) Dual inf 6.1653464e+10 (6)
# 9  Obj 1.1319977
# Optimal - objective value 1.1319977
# Optimal objective 1.131997703 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7ac4bdcf62a449b7aa8ff9a730d7c022-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7ac4bdcf62a449b7aa8ff9a730d7c022-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.047602393 (1) Dual inf 130.02703 (2)
# 0  Obj -0 Primal inf 0.047602393 (1) Dual inf 6.0927599e+10 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/bb783a3347304312bf563e5cab71a164-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/bb783a3347304312bf563e5cab71a164-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 243.32037 (2)
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 9.8546244e+10 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/670950dcc80e41d3ab13715c4ebe5136-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/670950dcc80e41d3ab13715c4ebe5136-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.022533609 (1) Dual inf 250.51844 (2)
# 0  Obj -0 Primal inf 0.022533609 (1) Dual inf 9.4211647e+10 (6)
# 4  Obj 1.2548583
# Optimal - objective value 1.2548583
# Optimal objective 1.254858322 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/441ef1b6ba3c4ffa8718f466f5192815-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/441ef1b6ba3c4ffa8718f466f5192815-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.032372636 (1) Dual inf 159.58846 (2)
# 0  Obj -0 Primal inf 0.032372636 (1) Dual inf 5.2831284e+10 (6)
# 6  Obj 1.0663216
# Optimal - objective value 1.0663216
# Optimal objective 1.066321637 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/352915dd70d04625ab6da4dd9445cdf9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/352915dd70d04625ab6da4dd9445cdf9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.029390737 (1) Dual inf 172.51705 (2)
# 0  Obj -0 Primal inf 0.029390737 (1) Dual inf 5.2152088e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0741218193f643acbffec0abd637e5cf-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0741218193f643acbffec0abd637e5cf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 107.80925 (2)
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 1.1173613e+11 (6)
# 6  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5bc7cca1e03a44cc85a9182cb45ef4b7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5bc7cca1e03a44cc85a9182cb45ef4b7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0074976285 (1) Dual inf 408.77458 (2)
# 0  Obj -0 Primal inf 0.0074976285 (1) Dual inf 1.1153354e+11 (6)
# 5  Obj 2.489356
# Optimal - objective value 2.489356
# Optimal objective 2.489355974 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9ae7d8b05fad423b87543fd6dede9c1e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9ae7d8b05fad423b87543fd6dede9c1e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.012679423 (1) Dual inf 115.25967 (2)
# 0  Obj -0 Primal inf 0.012679423 (1) Dual inf 9.3828389e+10 (6)
# 7  Obj 1.0373602
# Optimal - objective value 1.0373602
# Optimal objective 1.037360193 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/291b173cd80a4686b3c321fc880a92e8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/291b173cd80a4686b3c321fc880a92e8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.011511494 (1) Dual inf 244.22549 (2)
# 0  Obj -0 Primal inf 0.011511494 (1) Dual inf 9.4215987e+10 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c831191c77b2402c881e105b7754f9ff-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c831191c77b2402c881e105b7754f9ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 121.62492 (2)
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 1.1303689e+11 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/cc120158ad8c42609dcdd4e5eccf2c96-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/cc120158ad8c42609dcdd4e5eccf2c96-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.063642256 (1) Dual inf 172.31206 (2)
# 0  Obj -0 Primal inf 0.063642256 (1) Dual inf 8.976707e+10 (6)
# 7  Obj 2.0633472
# Optimal - objective value 2.0633472
# Optimal objective 2.063347183 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/974eb49a82e44ca5b9dbed958150d258-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/974eb49a82e44ca5b9dbed958150d258-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.10393707 (1) Dual inf 157.37685 (2)
# 0  Obj -0 Primal inf 0.10393707 (1) Dual inf 1.382571e+11 (6)
# 7  Obj 2.2172144
# Optimal - objective value 2.2172144
# Optimal objective 2.217214397 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9c3983a521fc45ffbfe8f69067faa7ff-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9c3983a521fc45ffbfe8f69067faa7ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# ...
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.074774004 (1) Dual inf 24.903719 (2)
# 0  Obj -0 Primal inf 0.074774004 (1) Dual inf 1.9897995e+11 (6)
# 6  Obj 2.0859951
# Optimal - objective value 2.0859951
# Optimal objective 2.085995086 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/838d2bd2f20441e8beae8755e0d422cd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/838d2bd2f20441e8beae8755e0d422cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.027542503 (1) Dual inf 139.21493 (2)
# 0  Obj -0 Primal inf 0.027542503 (1) Dual inf 7.2023269e+10 (6)
# 9  Obj 0.98712647
# Optimal - objective value 0.98712647
# Optimal objective 0.9871264744 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8c274faa1d2e4451a433a58ce075be93-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8c274faa1d2e4451a433a58ce075be93-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.05356848 (1) Dual inf 27.308701 (2)
# 0  Obj -0 Primal inf 0.05356848 (1) Dual inf 1.8769948e+11 (6)
# 7  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/329c9ac90faa4446836a290ae1c03384-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/329c9ac90faa4446836a290ae1c03384-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.049356083 (1) Dual inf 182.39697 (2)
# 0  Obj -0 Primal inf 0.049356083 (1) Dual inf 6.4414257e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e9a5f7b5dbe84c04ab5d5b2f3a6b1c8f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e9a5f7b5dbe84c04ab5d5b2f3a6b1c8f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.080497512 (1) Dual inf 44.400361 (2)
# 0  Obj -0 Primal inf 0.080497512 (1) Dual inf 1.1483193e+11 (6)
# 10  Obj 1.2091427
# Optimal - objective value 1.2091427
# Optimal objective 1.209142695 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b43f777530cc46859feff0bfe0db6c1d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b43f777530cc46859feff0bfe0db6c1d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.053795794 (1) Dual inf 190.94782 (2)
# 0  Obj -0 Primal inf 0.053795794 (1) Dual inf 6.480267e+10 (6)
# 7  Obj 1.1747284
# Optimal - objective value 1.1747284
# Optimal objective 1.174728424 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3531b19aa2664dc188666e3f18893fb9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/3531b19aa2664dc188666e3f18893fb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.089874351 (1) Dual inf 46.731536 (2)
# 0  Obj -0 Primal inf 0.089874351 (1) Dual inf 1.1592667e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/524560c17c1e41379c49b63f1fdbbc2a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/524560c17c1e41379c49b63f1fdbbc2a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.02833726 (1) Dual inf 210.98254 (2)
# 0  Obj -0 Primal inf 0.02833726 (1) Dual inf 5.663204e+10 (6)
# 7  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/074b7beee67c4ced8247870f2643e5ba-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/074b7beee67c4ced8247870f2643e5ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.037382444 (1) Dual inf 51.044969 (2)
# 0  Obj -0 Primal inf 0.037382444 (1) Dual inf 1.0523298e+11 (6)
# 7  Obj 1.2297949
# Optimal - objective value 1.2297949
# Optimal objective 1.229794923 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/324328ae10eb4d52937482535d7206bb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/324328ae10eb4d52937482535d7206bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.03481461 (1) Dual inf 221.85264 (2)
# 0  Obj -0 Primal inf 0.03481461 (1) Dual inf 6.1622629e+10 (6)
# 6  Obj 0.85972844
# Optimal - objective value 0.85972844
# Optimal objective 0.8597284422 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9ab0c918f8044ab8a064fbc3fd3830af-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9ab0c918f8044ab8a064fbc3fd3830af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.041849486 (1) Dual inf 53.457793 (2)
# 0  Obj -0 Primal inf 0.041849486 (1) Dual inf 9.848024e+10 (6)
# 6  Obj 0.99328206
# Optimal - objective value 0.99328206
# Optimal objective 0.9932820586 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/17f7cc121a9449f58856bc3a5ae4a0da-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/17f7cc121a9449f58856bc3a5ae4a0da-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.010872132 (1) Dual inf 311.85375 (2)
# 0  Obj -0 Primal inf 0.010872132 (1) Dual inf 9.7939907e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/270e41ab3843461e914b980c27a43037-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/270e41ab3843461e914b980c27a43037-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0052602114 (1) Dual inf 73.217688 (2)
# 0  Obj -0 Primal inf 0.0052602114 (1) Dual inf 2.1136065e+11 (6)
# 6  Obj 1.3488615
# Optimal - objective value 1.3488615
# Optimal objective 1.348861488 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c2638dabf7db4f0f97d22c448044d1c7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c2638dabf7db4f0f97d22c448044d1c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.011004394 (1) Dual inf 333.35298 (2)
# 0  Obj -0 Primal inf 0.011004394 (1) Dual inf 1.1642423e+11 (6)
# 7  Obj 1.1086388
# Optimal - objective value 1.1086388
# Optimal objective 1.10863882 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f3c76cadf07c45fdb59d2a7bd0ab48ff-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f3c76cadf07c45fdb59d2a7bd0ab48ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0052159818 (1) Dual inf 75.981579 (2)
# 0  Obj -0 Primal inf 0.0052159818 (1) Dual inf 2.6810599e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# 20

# %%
effective_score_list
# Out:
# [0.6478839228419181,
#  9.107597886429424,
#  1.412367955076913,
#  1.268718797583267,
#  0.5603160855960033,
#  0.9058484102939512,
#  0.08643045002139176,
#  0.9376412318085042,
#  1.0848088802098241,
#  3.422240874527027,
#  0.9646778870271625,
#  0.6858926508040385,
#  0.9548016618981364,
#  0.9458166790065378,
#  0.8486611502240468,
#  0.07367248644987102,
#  1.4536848276304948,
#  1.0145420044522766,
#  1.1839805844664535,
#  1.1030332679075177]

# %%
Malquits_model.Malquist_primal_model[0]
# Out:
# Efficiency_Calculation_from_PrimalEquation:
# MAXIMIZE
# 263.1*u_0 + 4.51*u_1 + 0.0
# SUBJECT TO
# _C1: - 263.1 u_0 - 4.51 u_1 + 40.76 v_0 + 98.1 v_1 + 13.568 v_2 + 4.6 v_3 >= 0
#
# _C2: - 108.54 u_0 - 5.14 u_1 + 12.53 v_0 + 15.9 v_1 + 21.19 v_2 + 43.8 v_3
#  >= 0
#
# _C3: - 193.29 u_0 - 3 u_1 + 16.31 v_0 + 72.5 v_1 + 31.66 v_2 + 13.125 v_3 >= 0
#
# _C4: - 327.83 u_0 - 4.01 u_1 + 27.9 v_0 + 62.9 v_1 + 67.97 v_2 + 7.175 v_3
#  >= 0
#
# _C5: - 172.16 u_0 - 4.78 u_1 + 155.4 v_0 + 88.1 v_1 + 1149.34 v_2 + 5 v_3 >= 0
#
# _C6: 40.76 v_0 + 98.1 v_1 + 13.568 v_2 + 4.6 v_3 = 1
#
# VARIABLES
# u_0 Continuous
# u_1 Continuous
# v_0 Continuous
# v_1 Continuous
# v_2 Continuous
# v_3 Continuous

# %%
Malquits_model.Malquist_primal_model[1]
# Out:
# Efficiency_Calculation_from_PrimalEquation:
# MAXIMIZE
# 237.57*u_0 + 4.79*u_1 + 0.0
# SUBJECT TO
# _C1: - 263.1 u_0 - 4.51 u_1 + 40.61 v_0 + 95.8 v_1 + 10.176 v_2 + 2.1 v_3 >= 0
#
# _C2: - 108.54 u_0 - 5.14 u_1 + 12.3 v_0 + 14.6 v_1 + 19.83 v_2 + 36.7 v_3 >= 0
#
# _C3: - 193.29 u_0 - 3 u_1 + 14.62 v_0 + 61.8 v_1 + 28.43 v_2 + 12.55 v_3 >= 0
#
# _C4: - 327.83 u_0 - 4.01 u_1 + 27.95 v_0 + 58.4 v_1 + 58.13 v_2 + 11.45 v_3
#  >= 0
#
# _C5: - 172.16 u_0 - 4.78 u_1 + 164.75 v_0 + 86.1 v_1 + 1202.38 v_2 + 5 v_3
#  >= 0
#
# _C6: 40.76 v_0 + 98.1 v_1 + 13.568 v_2 + 4.6 v_3 = 1
#
# VARIABLES
# u_0 Continuous
# u_1 Continuous
# v_0 Continuous
# v_1 Continuous
# v_2 Continuous
# v_3 Continuous
