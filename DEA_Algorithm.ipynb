# %%
import pandas as pd
import pulp
from pulp import GLPK
import numpy as np

# %%
df = pd.read_csv("Dea_data2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Company                                         25 non-null     object
#  1   Year                                            25 non-null     int64
#  2   GHG_Intensity                                   25 non-null     float64
#  3   Energy_Intensity_per_Sales                      25 non-null     float64
#  4   NonRenewable_Energy_Consumption_and_Production  25 non-null     float64
#  5   Water_Intensity_Per_Sales                       25 non-null     float64
#  6   NonRecycled_Waste_ration                        25 non-null     float64
#  7   ESG_Score                                       25 non-null     float64
#  8   GHG_1                                           25 non-null     float64
#  9   GHG_2                                           25 non-null     float64
#  10  GHG_3                                           25 non-null     float64
#  11  1_plus_2                                        25 non-null     float64
#  12  1_plus_2_plus_3                                 25 non-null     float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
df.replace(0, 0.01, inplace=True)
df.head()
# Out:
#           Company  Year  GHG_Intensity  Energy_Intensity_per_Sales  \
# 0  SONY US Equity  2023         283.35                       96.22
# 1  SONY US Equity  2022         255.60                       95.00
# 2  SONY US Equity  2021         283.36                       40.75
# 3  SONY US Equity  2020         237.57                       40.61
# 4  SONY US Equity  2019         263.10                       40.76
#
#    NonRenewable_Energy_Consumption_and_Production  Water_Intensity_Per_Sales  \
# 0                                            89.9                      0.010
# 1                                            95.1                      3.392
# 2                                            94.4                      6.784
# 3                                            95.8                     10.176
# 4                                            98.1                     13.568
#
#    NonRecycled_Waste_ration  ESG_Score  GHG_1  GHG_2   GHG_3  1_plus_2  \
# 0                       3.3       5.09   2.72   8.73  250.54     11.45
# 1                       2.0       5.03   2.63  12.28  227.68     14.92
# 2                       2.0       4.97   2.36  10.44  226.74     12.80
# 3                       2.1       4.79   2.41  15.22  190.47     17.63
# 4                       4.6       4.51   2.48  15.58  216.95     18.05
#
#    1_plus_2_plus_3
# 0           261.99
# 1           242.60
# 2           239.54
# 3           208.09
# 4           235.00

# %%
df.shape
# Out:
# (25, 13)

# %%
class DEA_models:
    def __init__(self):
        DEFALUT_inputs_t1 = np.array(df[df['Year'] == 2019][['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                                'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        DEFALUT_outputs_t1 = np.array(df[df['Year'] == 2019][['GHG_Intensity', 'ESG_Score']])
        self.num_dmus = DEFALUT_inputs_t1.shape[0]
        self.num_inputs = DEFALUT_inputs_t1.shape[1]
        self.num_outputs = DEFALUT_outputs_t1.shape[1]

        self.result_matrix = pd.DataFrame(columns=['SONY', 'APPL', 'DELL', 'HPE', 'SAMSUNG', 'EorT', 'Period'])
        self.Malquist_models = []
        self.Malquist_concepted_model=[]
        self.Malquist_primal_model=[]
        self.result_FromCRSPrimal = pd.DataFrame(columns=['SONY', 'APPL', 'DELL', 'HPE', 'SAMSUNG', 'EorT', 'Period'])

        # for SBM model
        self.S_minus_list = []
        #self.S_plus_list = []
        self.rho_list = []
        self.SBM_result = pd.DataFrame(columns=['Conpany', 'Year', 'Rho'])

    # the Efficiency has been moved to function calculate_efficiency_from_concept
    # the calculate_efficiency is reused for the confirmation of the outliners   
    """
    def calculate_efficiency(self, inputs, outputs, reference_inputs, reference_outputs,i):
        model = pulp.LpProblem("Efficiency_Calculation", pulp.LpMaximize)
        lambdas = [pulp.LpVariable(f"lambda_{j}", lowBound=0) for j in range(self.num_dmus)]
        model += pulp.lpSum([lambdas[j] * reference_outputs[j, 0] for j in range(self.num_dmus)])
        for k in range(self.num_inputs):
            model += pulp.lpSum([lambdas[j] * reference_inputs[j, k] for j in range(self.num_dmus)]) <= inputs[i, k]
        model += pulp.lpSum(lambdas) == 0.1
        # model += pulp.lpSum(lambdas) == 1

        # collect models dor debug
        self.Malquist_models.append(model)
        
        model.solve()
            
        if model.status == pulp.LpStatusOptimal:
            self.efficiency_score = pulp.value(pulp.lpSum([lambdas[j] * reference_outputs[j, 0] for j in range(self.num_dmus)])) / outputs[i, 0]
        else:
            self.efficiency_score = -1
            
        return self.efficiency_score
    """

    def calculate_efficiency_from_concept(self, inputs, outputs, reference_inputs, reference_outputs, i):
        model = pulp.LpProblem("Efficiency_Calculation_from_concept", pulp.LpMinimize)

        lambdas = [pulp.LpVariable(f"lambda_{j}", lowBound=0) for j in range(self.num_dmus)]
        Theta = pulp.LpVariable("Theta", lowBound=0) 
   
        model += Theta
        for k in range(self.num_inputs):
            model += (pulp.lpSum([lambdas[j] * reference_inputs[j, k] for j in range(self.num_dmus)]) <= Theta * inputs[i, k])
        for k in range(self.num_outputs):
            model += (pulp.lpSum([lambdas[j] * reference_outputs[j, k] for j in range(self.num_dmus)]) >= outputs[i, k])

        self.Malquist_concepted_model.append(model)
        model.solve()

        if pulp.LpStatus[model.status] == "Optimal":
            efficiency_score = Theta.value()
        else:
            # change the default
            efficiency_score = 0

        return efficiency_score

    def CRS_InputOriented_Primal_equation(self, inputs, outputs, reference_inputs, reference_outputs, DMU_Index):

        lp_problem = pulp.LpProblem("Efficiency_Calculation_from_PrimalEquation", pulp.LpMaximize)
        v = [pulp.LpVariable(f"v_{i}", lowBound=0) for i in range(self.num_inputs)] 
        u = [pulp.LpVariable(f"u_{r}", lowBound=0) for r in range(self.num_outputs)]
        #print(lp_problem)
        lp_problem += pulp.lpSum(u[r] * reference_outputs[DMU_Index][r] for r in range(self.num_outputs))
        #print(lp_problem)
        for j in range(self.num_dmus):
            lp_problem += (
                pulp.lpSum(v[i] * reference_inputs[j, i] for i in range(self.num_inputs)) - pulp.lpSum(u[r] * reference_outputs[j, r] for r in range(self.num_outputs)) >= 0
            )
        #print(lp_problem)
        lp_problem += pulp.lpSum(v[i] * inputs[DMU_Index][i] for i in range(self.num_inputs)) == 1
        #print(lp_problem)
        self.Malquist_primal_model.append(lp_problem)
        lp_problem.solve()

        if pulp.LpStatus[lp_problem.status] == "Optimal":
            efficiency_score = pulp.value(lp_problem.objective)
        else:
            efficiency_score = None

        return efficiency_score

    def Primal_equation_test(self):
        effective_score_list = []
        self.test_model_catch = []
        for year_ in [2019, 2020, 2021, 2022]:

            in_t1, out_t1, in_t2, out_t2 = self.return_periods(year_)
            EC_list = []
            TC_list = []
            MI_list = []

            for Dmu_index in range(self.num_dmus):
                eff_t1_t1 = self.CRS_InputOriented_Primal_equation(in_t1, out_t1, in_t1, out_t1, Dmu_index)
                eff_t1_t2 = self.CRS_InputOriented_Primal_equation(in_t1, out_t1, in_t2, out_t2, Dmu_index)
                eff_t2_t1 = self.CRS_InputOriented_Primal_equation(in_t2, out_t2, in_t1, out_t1, Dmu_index)
                eff_t2_t2 = self.CRS_InputOriented_Primal_equation(in_t2, out_t2, in_t2, out_t2, Dmu_index)
                
                if all(v is not None for v in [eff_t1_t1, eff_t2_t2, eff_t1_t2, eff_t2_t1]):
                    EC = eff_t2_t2 / eff_t1_t1 if eff_t1_t1 != None else None
                    TC = np.sqrt((eff_t1_t2 * eff_t2_t2) / (eff_t1_t1 * eff_t2_t1)) if all(v != None for v in [eff_t1_t1, eff_t2_t1]) else None
                    malmquist_index = EC * TC if EC is not None and TC is not None else None
                    #print(malmquist_index)
                    effective_score_list.append(malmquist_index)
                    EC_list.append(EC)
                    TC_list.append(TC)
                    MI_list.append(malmquist_index)
                else:
                    print("No feasible solution.")
                    effective_score_list.append(np.nan)
            
            MI_list.extend(['ETC',f'{year_}_{year_+1}'])
            EC_list.extend(['EC',f'{year_}_{year_+1}'])
            TC_list.extend(['TC',f'{year_}_{year_+1}'])
            self.result_FromCRSPrimal.loc[len(self.result_FromCRSPrimal)] = MI_list
            self.result_FromCRSPrimal.loc[len(self.result_FromCRSPrimal)] = EC_list
            self.result_FromCRSPrimal.loc[len(self.result_FromCRSPrimal)] = TC_list

        return effective_score_list

    def return_periods(self, year_):
        inputs_t1 = np.array(df[df['Year'] == year_][['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                            'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        outputs_t1 = np.array(df[df['Year'] == year_][['GHG_Intensity', 'ESG_Score']])
        inputs_t2 = np.array(df[df['Year'] == (year_+1)][['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                            'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        outputs_t2 = np.array(df[df['Year'] == (year_+1)][['GHG_Intensity', 'ESG_Score']])
        
        return inputs_t1, outputs_t1, inputs_t2, outputs_t2

    def Malquist_result(self):
        collection_slices = []
        for year_ in [2019, 2020, 2021, 2022]:
            in_t1, out_t1, in_t2, out_t2 = self.return_periods(year_)

            malmquist_indices = []
            EC_list = []
            TC_list = []
            for Dmu_index in range(self.num_dmus):
                """
                eff_t1_t1 = self.calculate_efficiency(in_t1, out_t1, in_t1, out_t1, Dmu_index)
                eff_t1_t2 = self.calculate_efficiency(in_t1, out_t1, in_t2, out_t2, Dmu_index)
                eff_t2_t1 = self.calculate_efficiency(in_t2, out_t2, in_t1, out_t1, Dmu_index)
                eff_t2_t2 = self.calculate_efficiency(in_t2, out_t2, in_t2, out_t2, Dmu_index)
                #print(eff_t1_t1, eff_t1_t2, eff_t2_t1, eff_t2_t2)
                """
                # Test another way to calculate the efficiency
                eff_t1_t1 = self.calculate_efficiency_from_concept(in_t1, out_t1, in_t1, out_t1, Dmu_index)
                eff_t1_t2 = self.calculate_efficiency_from_concept(in_t1, out_t1, in_t2, out_t2, Dmu_index)
                eff_t2_t1 = self.calculate_efficiency_from_concept(in_t2, out_t2, in_t1, out_t1, Dmu_index)
                eff_t2_t2 = self.calculate_efficiency_from_concept(in_t2, out_t2, in_t2, out_t2, Dmu_index)
                
                if all(v is not None for v in [eff_t1_t1, eff_t2_t2, eff_t1_t2, eff_t2_t1]):
                    # use string to alert no-optimal issue
                    EC = eff_t2_t2 / eff_t1_t1 if eff_t1_t1 != 0 else np.nan
                    TC = np.sqrt((eff_t1_t2 * eff_t2_t2) / (eff_t1_t1 * eff_t2_t1)) if all(v != 0 for v in [eff_t1_t1, eff_t2_t1]) else np.nan
                    #print(EC, TC)
                    EC_list.append(EC)
                    TC_list.append(TC)
                    malmquist_index = EC * TC if EC is not np.nan and TC is not np.nan else np.nan
                    malmquist_indices.append(malmquist_index)
                else:
                    malmquist_indices.append(None)

            malmquist_indices.extend(['ETC',f'{year_}_{year_+1}'])
            collection_slices.append(malmquist_indices)
            EC_list.extend(['EC',f'{year_}_{year_+1}'])
            TC_list.extend(['TC',f'{year_}_{year_+1}'])

            self.result_matrix.loc[len(self.result_matrix)] = malmquist_indices
            self.result_matrix.loc[len(self.result_matrix)] = EC_list
            self.result_matrix.loc[len(self.result_matrix)] = TC_list
    # input_oriented
    def SBM_model(self):
        SBM_IN = np.array(df[['Energy_Intensity_per_Sales', 'NonRenewable_Energy_Consumption_and_Production',
                            'Water_Intensity_Per_Sales', 'NonRecycled_Waste_ration']])
        SBM_OUT = np.array(df[['GHG_Intensity', 'ESG_Score']])
        n = len(SBM_IN)
        m = len(SBM_IN[0])
        s = len(SBM_OUT[0])

        # type in __init__
        # self.sbm_scores = []
        for DMU_NUM in range(n):
            prob = pulp.LpProblem("SBM_Model", pulp.LpMinimize)
            lambdas = [pulp.LpVariable(f"lambda_{k}", lowBound=0) for k in range(n)]
            s_minus = [pulp.LpVariable(f"s_minus_{i}", lowBound=0) for i in range(m)]
            #s_plus = [pulp.LpVariable(f"s_plus_{r}", lowBound=0) for r in range(s)]

            input_term = (1 / m) * sum([(s_minus[i]*(1.0/SBM_IN[DMU_NUM][i])) for i in range(m)])
            #output_term = (1 / s) * sum([(s_plus[r]*(1.0/SBM_OUT[DMU_NUM][r])) for r in range(s)])
            rho = 1-input_term
            prob += rho

            for i in range(m):
                prob += (pulp.lpSum([SBM_IN[k][i] * lambdas[k] for k in range(n)]) + s_minus[i] == SBM_IN[DMU_NUM][i])

            for r in range(s):
                prob += (pulp.lpSum([SBM_OUT[k][r] * lambdas[k] for k in range(n)]) >= SBM_OUT[DMU_NUM][r])
            
            prob.solve()

            if pulp.LpStatus[prob.status] == "Optimal":
                self.rho_list.append([DMU_NUM, pulp.value(rho)])
                for i in range(m):
                    print(f"s_minus_{i}:", pulp.value(s_minus[i]))
                    self.S_minus_list.append([DMU_NUM, pulp.value(s_minus[i])])
                """
                for r in range(s):
                    print(f"s_plus_{r}:", pulp.value(s_plus[r]))
                    self.S_plus_list.append(pulp.value(s_plus[r]))
                """
            else:
                self.rho_list.append([DMU_NUM, np.nan])
                print("No optimal solution found.")
        """
        for j, score in enumerate(self.rho_list):
            print(f"DMU {j+1} SBM Efficiency Score: {score}")
        """
        for i in self.rho_list:
            Company_name = df.iloc[i[0]]['Company']
            Year_ = df.iloc[i[0]]['Year']
            self.SBM_result.loc[len(self.SBM_result)] = [Company_name, Year_, i[1]]

# %%
Malquits_model = DEA_models()
Malquits_model.Malquist_result()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7d66464f208d40fbbc1b9bfc314b53a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7d66464f208d40fbbc1b9bfc314b53a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.135062 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e1f54432cab24dfaa6f987d5038779c5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e1f54432cab24dfaa6f987d5038779c5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.67202997 (2)
# 8  Obj 0.9913049
# Optimal - objective value 0.9913049
# Optimal objective 0.9913048986 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0ebe293ce2a54059a1f9e30b0e363a68-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0ebe293ce2a54059a1f9e30b0e363a68-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.4621574 (2)
# 8  Obj 2.3264703
# Optimal - objective value 2.3264703
# Optimal objective 2.326470278 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2cba7593711748f18ad341b2f60be118-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2cba7593711748f18ad341b2f60be118-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.60822091 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0d2d1104857e4d70be8d0c238fa2113f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0d2d1104857e4d70be8d0c238fa2113f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5639194 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/804256f277414918a2294f2707c21b28-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/804256f277414918a2294f2707c21b28-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.28364612 (2)
# 5  Obj 1.003098
# Optimal - objective value 1.003098
# Optimal objective 1.003098023 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4fdacfba917b4a77bfc5dca1c7930b54-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4fdacfba917b4a77bfc5dca1c7930b54-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 108.2508 (2)
# 5  Obj 117.05747
# Optimal - objective value 117.05747
# Optimal objective 117.0574714 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/565921e5e31144de830c6b2f8a6131d5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/565921e5e31144de830c6b2f8a6131d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.2505418 (2)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f0ca50d14e0e4226a95cb0838d2a1000-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f0ca50d14e0e4226a95cb0838d2a1000-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5032842 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c7291937157e4d2880acb6c29f519bb1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c7291937157e4d2880acb6c29f519bb1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.49310394 (2)
# 7  Obj 0.59054787
# Optimal - objective value 0.59054787
# Optimal objective 0.5905478719 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/42934bf5d2cc4f1d94cc4e09b06f39ef-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/42934bf5d2cc4f1d94cc4e09b06f39ef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.1367163 (2)
# 5  Obj 1.791208
# Optimal - objective value 1.791208
# Optimal objective 1.791208039 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0a5b28ab669e42919b701cb5b9e4e1c0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0a5b28ab669e42919b701cb5b9e4e1c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.78086268 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8d0264037c5e46c696d1b25f3fdb304e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8d0264037c5e46c696d1b25f3fdb304e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.3250658 (2)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c6934885185c4542b85a6fd9ba3e6979-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c6934885185c4542b85a6fd9ba3e6979-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.83422457 (2)
# 9  Obj 1.1044558
# Optimal - objective value 1.1044558
# Optimal objective 1.104455831 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d88cb9047a9a42d0b67af46b4ebfc853-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d88cb9047a9a42d0b67af46b4ebfc853-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.6796951 (2)
# 5  Obj 1.3546111
# Optimal - objective value 1.3546111
# Optimal objective 1.354611051 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1e508e2585fa4f12bf0bd268e9c10588-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1e508e2585fa4f12bf0bd268e9c10588-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0082225 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a9e4fd084e80496892177d39d58c5a9a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a9e4fd084e80496892177d39d58c5a9a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7780414 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ca789af0445e4a5781da8b0fee434982-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ca789af0445e4a5781da8b0fee434982-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.44331608 (2)
# 7  Obj 0.59543568
# Optimal - objective value 0.59543568
# Optimal objective 0.5954356815 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b768d08f5d844437a92a7453efc40bc2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b768d08f5d844437a92a7453efc40bc2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.779118 (2)
# 6  Obj 1.0617677
# Optimal - objective value 1.0617677
# Optimal objective 1.061767704 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d5534bd9f48746c5a922d45c6615d273-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d5534bd9f48746c5a922d45c6615d273-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.43238832 (2)
# 7  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9a07f6cf03f84fb9939cd7504e961706-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9a07f6cf03f84fb9939cd7504e961706-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.60822091 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a24f821a21d440f9888ae83ddcc483dc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a24f821a21d440f9888ae83ddcc483dc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.989497 (2)
# 6  Obj 0.96365609
# Optimal - objective value 0.96365609
# Optimal objective 0.9636560949 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/80da2548d8a0411eb8e5255834e59b7c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/80da2548d8a0411eb8e5255834e59b7c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.3510447 (2)
# 8  Obj 1.7891148
# Optimal - objective value 1.7891148
# Optimal objective 1.789114787 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b233a0c8fec14261a5bf730635527030-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b233a0c8fec14261a5bf730635527030-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.2200898 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/66d0e2d055ca485cb7bf9a330889efdf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/66d0e2d055ca485cb7bf9a330889efdf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.2505418 (2)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/844f580504d64c4bb7bfcccb32ca2ad9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/844f580504d64c4bb7bfcccb32ca2ad9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 108.65447 (2)
# 5  Obj 88.689012
# Optimal - objective value 88.689012
# Optimal objective 88.68901244 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5e4927264fcc49429dfff31220869881-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5e4927264fcc49429dfff31220869881-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.21656618 (2)
# 4  Obj 0.84950063
# Optimal - objective value 0.84950063
# Optimal objective 0.8495006341 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/09b4a188e89d4b589b497cf8a7fae904-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/09b4a188e89d4b589b497cf8a7fae904-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5461645 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f3b657abd7874e76ac90dc03a2dc14ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f3b657abd7874e76ac90dc03a2dc14ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.78086268 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a3d028639dc1433ea991c89f8388c1ba-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a3d028639dc1433ea991c89f8388c1ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.0193275 (2)
# 8  Obj 0.98024867
# Optimal - objective value 0.98024867
# Optimal objective 0.9802486685 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/397b5730b0c043f5b410cf977db2ca0b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/397b5730b0c043f5b410cf977db2ca0b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.78687286 (2)
# 5  Obj 1.1510907
# Optimal - objective value 1.1510907
# Optimal objective 1.151090679 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a8915876bfe34bfbafbb3ee68ac89bf4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a8915876bfe34bfbafbb3ee68ac89bf4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.0437461 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/75ac153cd7634db8ba8824ea11afc639-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/75ac153cd7634db8ba8824ea11afc639-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0082225 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e9a43a8e7f984ca78fc8a71443b032c2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e9a43a8e7f984ca78fc8a71443b032c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5267419 (2)
# 6  Obj 1.1320232
# Optimal - objective value 1.1320232
# Optimal objective 1.132023205 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/53ced45bd2db48b8b2ccd68b9d2e8ffb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/53ced45bd2db48b8b2ccd68b9d2e8ffb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0505564 (2)
# 5  Obj 1.1534585
# Optimal - objective value 1.1534585
# Optimal objective 1.153458454 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e907c36268404aca8dac184a97384fe9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e907c36268404aca8dac184a97384fe9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.7126877 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/75f2a46d4e4f4ff188341cdc076a6a33-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/75f2a46d4e4f4ff188341cdc076a6a33-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 0.43238832 (2)
# 7  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/27ffdac6aa654099a3cc30bdb097034d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/27ffdac6aa654099a3cc30bdb097034d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7450756 (2)
# 5  Obj 0.94187454
# Optimal - objective value 0.94187454
# Optimal objective 0.9418745398 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f5eeb6d71e6a499291a6408b00e56786-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f5eeb6d71e6a499291a6408b00e56786-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7257832 (2)
# 5  Obj 2.5576029
# Optimal - objective value 2.5576029
# Optimal objective 2.557602946 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a3efd0423fb744a18dd319cdfbfc0326-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a3efd0423fb744a18dd319cdfbfc0326-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 3.8799179 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ec168f3d715649a4bf6591f795c86a5d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ec168f3d715649a4bf6591f795c86a5d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.2200898 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9ef0a3f479f248399cb9207699ba030a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9ef0a3f479f248399cb9207699ba030a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5467721 (2)
# 7  Obj 2.0214569
# Optimal - objective value 2.0214569
# Optimal objective 2.021456898 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f62ada75733143349bf4ce41707954b3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f62ada75733143349bf4ce41707954b3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5119611 (2)
# 7  Obj 2.0241449
# Optimal - objective value 2.0241449
# Optimal objective 2.024144869 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8fa04299095b49dfb0b05bc381e51c22-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8fa04299095b49dfb0b05bc381e51c22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.4150417 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2781ab1e28e14f0faeea22f0014da4b4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2781ab1e28e14f0faeea22f0014da4b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5461645 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7c978826b393498ca01ce108c75be2e6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7c978826b393498ca01ce108c75be2e6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.6563287 (2)
# 7  Obj 0.94432424
# Optimal - objective value 0.94432424
# Optimal objective 0.9443242424 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4dbc7fd2261248c29f82bce7bea6f5fc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4dbc7fd2261248c29f82bce7bea6f5fc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.624034 (2)
# 7  Obj 1.8951957
# Optimal - objective value 1.8951957
# Optimal objective 1.895195713 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fd8099e7cf6b4f9ba1d399992bad8c56-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/fd8099e7cf6b4f9ba1d399992bad8c56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5974745 (2)
# 4  Obj 1
# ...
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0c38ee7322d54882a20ab141e8cfeaa7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0c38ee7322d54882a20ab141e8cfeaa7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.5974745 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0a1f21df576444aa8082a0b4a7b9b38c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0a1f21df576444aa8082a0b4a7b9b38c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.3076607 (2)
# 9  Obj 2.4754695
# Optimal - objective value 2.4754695
# Optimal objective 2.475469488 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/daebba2bc71b497199778998fff1eed3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/daebba2bc71b497199778998fff1eed3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.4171166 (2)
# 7  Obj 0.88853885
# Optimal - objective value 0.88853885
# Optimal objective 0.8885388547 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/16b01f4ae1cb494792b6c480f36bb0fe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/16b01f4ae1cb494792b6c480f36bb0fe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.0981443 (2)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/eac968e0c08442938a85cbeceb73b2d3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/eac968e0c08442938a85cbeceb73b2d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.5296269 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e6d853c9832948ce9324a92f58f11794-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e6d853c9832948ce9324a92f58f11794-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.4587779 (2)
# 5  Obj 0.90708826
# Optimal - objective value 0.90708826
# Optimal objective 0.9070882626 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/be4f578d12524d0893fa2e5a5cd28be0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/be4f578d12524d0893fa2e5a5cd28be0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.8504452 (2)
# 9  Obj 1.5981008
# Optimal - objective value 1.5981008
# Optimal objective 1.59810083 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d61d55c7c5c04424877d2d98cb25f07a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d61d55c7c5c04424877d2d98cb25f07a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.6970717 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dae941dee86b4d46a1a002d23c0e6389-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dae941dee86b4d46a1a002d23c0e6389-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.8980217 (2)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2b6b0fc3e76648619b9b0fd523b5906c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2b6b0fc3e76648619b9b0fd523b5906c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.7152594 (2)
# 5  Obj 0.96966601
# Optimal - objective value 0.96966601
# Optimal objective 0.9696660131 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d12f91e4f1c548648144809b7c8198b4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d12f91e4f1c548648144809b7c8198b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 3.3128838 (2)
# 7  Obj 1.1042885
# Optimal - objective value 1.1042885
# Optimal objective 1.104288498 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4a5554eac1d0468f8a7ed0e74d62b7f0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4a5554eac1d0468f8a7ed0e74d62b7f0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 1.9154262 (2)
# 5  Obj 0.99328206
# Optimal - objective value 0.99328206
# Optimal objective 0.9932820586 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7cf92b98a7dd49979614d2a76f8f4670-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7cf92b98a7dd49979614d2a76f8f4670-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 4.3748772 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/04c2d814324a4ea9a1f5bfd2e8438ea6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/04c2d814324a4ea9a1f5bfd2e8438ea6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.4446539 (2)
# 6  Obj 1.0597712
# Optimal - objective value 1.0597712
# Optimal objective 1.059771185 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/646d36f8ea1a4b1b93ad32caa8d23336-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/646d36f8ea1a4b1b93ad32caa8d23336-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 4.5734812 (2)
# 9  Obj 1.3948792
# Optimal - objective value 1.3948792
# Optimal objective 1.39487918 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f142072b35334910b7e9bef01d5092ca-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f142072b35334910b7e9bef01d5092ca-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 47 RHS
# At line 54 BOUNDS
# At line 55 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj 0 Primal inf 2.654541 (2)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
Malquits_model.Malquist_concepted_model
# Out:
# [Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.76 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 98.1 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 13.568 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 4.6 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 263.1
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.51
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.76 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 98.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 13.568 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 4.6 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 263.1
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.51
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 237.57
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 237.57
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.53 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 15.9 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 21.19 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 43.8 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 108.54
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 5.14
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.53 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 15.9 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 21.19 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 43.8 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 108.54
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 5.14
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 99.39
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 99.39
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 16.31 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 72.5 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 31.66 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 13.125 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 193.29
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 3
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 16.31 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 72.5 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 31.66 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 13.125 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 193.29
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 307.01
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 307.01
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.9 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 62.9 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 67.97 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 7.175 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 327.83
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.01
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.9 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 62.9 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 67.97 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 7.175 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 327.83
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.01
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 396.7
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 396.7
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 155.4 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 88.1 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 1149.34 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 5 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 172.16
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 155.4 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 88.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1149.34 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 172.16
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.76 lambda_0 + 12.53 lambda_1 + 16.31 lambda_2
#   + 27.9 lambda_3 + 155.4 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 98.1 lambda_0 + 15.9 lambda_1 + 72.5 lambda_2
#   + 62.9 lambda_3 + 88.1 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 13.568 lambda_0 + 21.19 lambda_1 + 31.66 lambda_2
#   + 67.97 lambda_3 + 1149.34 lambda_4 <= 0
#
#  _C4: - 5 Theta + 4.6 lambda_0 + 43.8 lambda_1 + 13.125 lambda_2
#   + 7.175 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 263.1 lambda_0 + 108.54 lambda_1 + 193.29 lambda_2 + 327.83 lambda_3
#   + 172.16 lambda_4 >= 167.67
#
#  _C6: 4.51 lambda_0 + 5.14 lambda_1 + 3 lambda_2 + 4.01 lambda_3
#   + 4.78 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 167.67
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 237.57
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.61 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 95.8 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 10.176 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2.1 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 237.57
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.79
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 283.36
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 283.36
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 99.39
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.3 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 14.6 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 19.83 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.7 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 99.39
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 512
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 81.48
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 81.48
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 307.01
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.62 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 61.8 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 28.43 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 12.55 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 307.01
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.56
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 309.34
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 309.34
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 396.7
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.95 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 58.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 58.13 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.45 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 396.7
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.21
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 413.06
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 413.06
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 167.67
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 164.75 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 86.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 1202.38 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 5 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 167.67
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.98
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 156.48 Theta + 40.61 lambda_0 + 12.3 lambda_1 + 14.62 lambda_2
#   + 27.95 lambda_3 + 164.75 lambda_4 <= 0
#
#  _C2: - 83.7 Theta + 95.8 lambda_0 + 14.6 lambda_1 + 61.8 lambda_2
#   + 58.4 lambda_3 + 86.1 lambda_4 <= 0
#
#  _C3: - 1247.14 Theta + 10.176 lambda_0 + 19.83 lambda_1 + 28.43 lambda_2
#   + 58.13 lambda_3 + 1202.38 lambda_4 <= 0
#
#  _C4: - 4.2 Theta + 2.1 lambda_0 + 36.7 lambda_1 + 12.55 lambda_2
#   + 11.45 lambda_3 + 5 lambda_4 <= 0
#
#  _C5: 237.57 lambda_0 + 99.39 lambda_1 + 307.01 lambda_2 + 396.7 lambda_3
#   + 167.67 lambda_4 >= 680.69
#
#  _C6: 4.79 lambda_0 + 512 lambda_1 + 3.56 lambda_2 + 4.21 lambda_3
#   + 4.98 lambda_4 >= 5.07
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 156.48 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 83.7 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 1247.14 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 4.2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 680.69
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.07
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 283.36
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 40.75 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 94.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 6.784 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 283.36
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.97
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 95 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 95.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 3.392 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 255.6
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.03
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 95 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 95.1 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 3.392 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 2 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 255.6
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.03
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 81.48
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.86 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 14.1 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 17.4 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 36.5 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 81.48
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 61.92
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 61.92
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 309.34
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 14.44 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 53.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 25.58 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 11.975 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 309.34
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 3.63
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 337.1
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 337.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 413.06
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 27.52 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 54.1 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 51.1 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 15.725 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 413.06
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
#   + 54.1 lambda_3 + 83.7 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 6.784 lambda_0 + 17.4 lambda_1 + 25.58 lambda_2
#   + 51.1 lambda_3 + 1247.14 lambda_4 <= 0
#
#  _C4: - 20 Theta + 2 lambda_0 + 36.5 lambda_1 + 11.975 lambda_2
#   + 15.725 lambda_3 + 4.2 lambda_4 <= 0
#
#  _C5: 283.36 lambda_0 + 81.48 lambda_1 + 309.34 lambda_2 + 413.06 lambda_3
#   + 680.69 lambda_4 >= 361.1
#
#  _C6: 4.97 lambda_0 + 5.72 lambda_1 + 3.63 lambda_2 + 4.77 lambda_3
#   + 5.07 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 20 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 361.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 156.48 Theta + 40.75 lambda_0 + 10.86 lambda_1 + 14.44 lambda_2
#   + 27.52 lambda_3 + 156.48 lambda_4 <= 0
#
#  _C2: - 83.7 Theta + 94.4 lambda_0 + 14.1 lambda_1 + 53.4 lambda_2
# ...
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 95.1 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 3.392 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 2 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 255.6
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.03
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 96.22 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 89.9 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 0.01 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 3.3 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 283.35
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.09
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 96.22 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 89.9 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 0.01 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 3.3 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 283.35
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.09
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 61.92
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 9.67 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 7.7 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 15.9 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 36.9 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 61.92
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.92
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 11.68 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 16.8 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 16.96 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 44.7 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 44.65
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.66
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 11.68 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 16.8 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 16.96 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 44.7 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 44.65
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.66
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 337.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 12.35 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 52.8 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 20.65 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 11.4 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 337.1
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 3.59
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.62 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 49.7 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 16.88 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 9.6 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 349.49
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 10.62 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 49.7 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 16.88 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 9.6 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 349.49
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.78
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 20 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 361.1
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 24.05 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 52.4 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 49.17 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 20 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 361.1
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.72
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 20.18 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 62.45 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 40.97 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 13.7 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 438.65
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 20.18 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 62.45 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 40.97 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 13.7 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2
#   + 13.7 lambda_3 + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 438.65
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.77
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 157.98 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 75.3 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 1299.72 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 3.5 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 627.58
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 5.13
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 157.98 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 75.3 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 1299.72 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 3.5 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 627.58
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 5.13
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 198.52 Theta + 95 lambda_0 + 9.67 lambda_1 + 12.35 lambda_2
#   + 24.05 lambda_3 + 157.98 lambda_4 <= 0
#
#  _C2: - 74.5 Theta + 95.1 lambda_0 + 7.7 lambda_1 + 52.8 lambda_2
#   + 52.4 lambda_3 + 75.3 lambda_4 <= 0
#
#  _C3: - 1637.59 Theta + 3.392 lambda_0 + 15.9 lambda_1 + 20.65 lambda_2
#   + 49.17 lambda_3 + 1299.72 lambda_4 <= 0
#
#  _C4: - 2.9 Theta + 2 lambda_0 + 36.9 lambda_1 + 11.4 lambda_2 + 20 lambda_3
#   + 3.5 lambda_4 <= 0
#
#  _C5: 255.6 lambda_0 + 61.92 lambda_1 + 337.1 lambda_2 + 361.1 lambda_3
#   + 627.58 lambda_4 >= 725.33
#
#  _C6: 5.03 lambda_0 + 5.92 lambda_1 + 3.59 lambda_2 + 4.72 lambda_3
#   + 5.13 lambda_4 >= 4.95
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous,
#  Efficiency_Calculation_from_concept:
#  MINIMIZE
#  1*Theta + 0
#  SUBJECT TO
#  _C1: - 198.52 Theta + 96.22 lambda_0 + 11.68 lambda_1 + 10.62 lambda_2
#   + 20.18 lambda_3 + 198.52 lambda_4 <= 0
#
#  _C2: - 74.5 Theta + 89.9 lambda_0 + 16.8 lambda_1 + 49.7 lambda_2
#   + 62.45 lambda_3 + 74.5 lambda_4 <= 0
#
#  _C3: - 1637.59 Theta + 0.01 lambda_0 + 16.96 lambda_1 + 16.88 lambda_2
#   + 40.97 lambda_3 + 1637.59 lambda_4 <= 0
#
#  _C4: - 2.9 Theta + 3.3 lambda_0 + 44.7 lambda_1 + 9.6 lambda_2 + 13.7 lambda_3
#   + 2.9 lambda_4 <= 0
#
#  _C5: 283.35 lambda_0 + 44.65 lambda_1 + 349.49 lambda_2 + 438.65 lambda_3
#   + 725.33 lambda_4 >= 725.33
#
#  _C6: 5.09 lambda_0 + 5.66 lambda_1 + 4.78 lambda_2 + 4.77 lambda_3
#   + 4.95 lambda_4 >= 4.95
#
#  VARIABLES
#  Theta Continuous
#  lambda_0 Continuous
#  lambda_1 Continuous
#  lambda_2 Continuous
#  lambda_3 Continuous
#  lambda_4 Continuous]

# %%
for model_ in Malquits_model.Malquist_concepted_model:
    print(pulp.LpStatus[model_.status])
# Out:
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal
# Optimal

# %%
for v in Malquits_model.Malquist_concepted_model[8].variables():
    print(f"{v.name} = {v.varValue}")
# Out:
# Theta = 1.0
# lambda_0 = 0.0
# lambda_1 = 0.0
# lambda_2 = 1.0
# lambda_3 = 0.0
# lambda_4 = 0.0

# %%
#Malquits_model.result_matrix.to_csv("Malquist_Index.csv")
Malquits_model.result_matrix
# Out:
#         SONY       APPL      DELL       HPE   SAMSUNG EorT     Period
# 0   0.652762   0.092570  0.574189  0.902957  0.338977  ETC  2019_2020
# 1   1.000000   1.000000  1.000000  1.000000  0.589538   EC  2019_2020
# 2   0.652762   0.092570  0.574189  0.902957  0.574988   TC  2019_2020
# 3   0.733909  10.217698  0.922812  0.990665  1.340639  ETC  2020_2021
# 4   1.000000   1.000000  1.000000  1.000000  1.696242   EC  2020_2021
# 5   0.733909  10.217698  0.922812  0.990665  0.790358   TC  2020_2021
# 6   0.999336   0.705884  0.855162  1.089352  0.967881  ETC  2021_2022
# 7   1.000000   1.000000  1.000000  1.000000  1.000000   EC  2021_2022
# 8   0.999336   0.705884  0.855162  1.089352  0.967881   TC  2021_2022
# 9   0.065840   1.669132  0.753395  0.927638  0.871641  ETC  2022_2023
# 10  1.000000   1.000000  1.000000  0.993282  1.000000   EC  2022_2023
# 11  0.065840   1.669132  0.753395  0.933912  0.871641   TC  2022_2023

# %%
Malquits_model.SBM_model()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/33147914bbdf402ab65848ad975a9af8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/33147914bbdf402ab65848ad975a9af8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 3047.8908 - largest nonzero change 3.0212823e-05 ( 0.00057190936%) - largest zero change 2.8195717e-05
# 0  Obj 0 Primal inf 5.7942556 (6) Dual inf 3067.5753 (4)
# 0  Obj 0 Primal inf 5.7942556 (6) Dual inf 1.5519834e+13 (29)
# 5  Obj -5.3646363e-09
# Optimal - objective value -5.3646363e-09
# Optimal objective -5.364636314e-09 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 0.0
# s_minus_1: 1.7806384e-09
# s_minus_2: 2.1432967e-10
# s_minus_3: 1.9044239e-11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e6a3a7e84e524373b35bbc7972674b27-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e6a3a7e84e524373b35bbc7972674b27-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 17.060296 - largest nonzero change 1.8890932e-06 ( 1.4382056e-05%) - largest zero change 1.8529971e-06
# 0  Obj 0 Primal inf 6.3032919 (6) Dual inf 35.176504 (4)
# 0  Obj 0 Primal inf 6.3032919 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -7.9144372e-12
# Optimal - objective value -7.9144372e-12
# Optimal objective -7.914437194e-12 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 3.5665003e-09
# s_minus_1: 1.1753652e-09
# s_minus_2: 0.0
# s_minus_3: -3.6487232e-11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/40cc4bf78fd0479495c1958c173bbbc5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/40cc4bf78fd0479495c1958c173bbbc5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 17.060296 - largest nonzero change 1.8890932e-06 ( 1.4343277e-05%) - largest zero change 1.8529971e-06
# 0  Obj 0 Primal inf 6.2751398 (6) Dual inf 36.642232 (4)
# 0  Obj 0 Primal inf 6.2751398 (6) Dual inf 1.5519834e+13 (29)
# 5  Obj -1.8862947e-11
# Optimal - objective value -1.8862947e-11
# Optimal objective -1.886294652e-11 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 7.686595e-10
# s_minus_1: 1.7806676e-09
# s_minus_2: 1.2796688e-10
# s_minus_3: 3.7725859e-11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/798097d9c29c4abc907f6c2bb1bf14d4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/798097d9c29c4abc907f6c2bb1bf14d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 16.247901 - largest nonzero change 1.8036874e-06 ( 1.4516009e-05%) - largest zero change 1.7973671e-06
# 0  Obj 0 Primal inf 6.9700505 (6) Dual inf 34.299097 (4)
# 0  Obj 0 Primal inf 6.9700505 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.23810183
# Optimal - objective value -0.23810183
# Optimal objective -0.238101829 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 6.4474939
# s_minus_1: 16.677321
# s_minus_2: 4.4669602
# s_minus_3: 0.3792311
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d550324436f14b24b348bc10bdcda6a7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d550324436f14b24b348bc10bdcda6a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 10.370896 - largest nonzero change 9.0358923e-07 ( 1.4751907e-05%) - largest zero change 8.688408e-07
# 0  Obj 0 Primal inf 8.5394272 (6) Dual inf 24.57267 (4)
# 0  Obj 0 Primal inf 8.5394272 (6) Dual inf 1.5519834e+13 (29)
# 6  Obj -0.32757489
# Optimal - objective value -0.32757489
# Optimal objective -0.3275748922 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 2.9235905
# s_minus_1: 10.44952
# s_minus_2: 7.2690503
# s_minus_3: 2.7429983
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/edcec7c1bbd344c1808f497aa9a577c0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/edcec7c1bbd344c1808f497aa9a577c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 36.191587 - largest nonzero change 2.835893e-06 ( 6.7390872e-05%) - largest zero change 2.6619756e-06
# 0  Obj 0 Primal inf 15.74522 (6) Dual inf 65.249956 (4)
# 0  Obj 0 Primal inf 15.74522 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -0.83172167
# Optimal - objective value -0.83172167
# Optimal objective -0.8317216712 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 10.231454
# s_minus_1: 10.44584
# s_minus_2: 14.654836
# s_minus_3: 43.137626
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1adba77ebb5b4dc88a085b4c08ab6b2f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1adba77ebb5b4dc88a085b4c08ab6b2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 57.813702 - largest nonzero change 5.8869459e-06 ( 7.9646913e-05%) - largest zero change 5.7846557e-06
# 0  Obj 0 Primal inf 13.594853 (6) Dual inf 104.36963 (4)
# 0  Obj 0 Primal inf 13.594853 (6) Dual inf 1.5519834e+13 (29)
# 11  Obj -5.2698361e-11
# Optimal - objective value -5.2698361e-11
# Optimal objective -5.269836136e-11 - 11 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.9235223e-10
# s_minus_1: -4.5989836e-11
# s_minus_2: 8.8129122e-10
# s_minus_3: 3.6930382e-09
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e4f93edb53684d3182718d7aa7607118-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e4f93edb53684d3182718d7aa7607118-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 38.924285 - largest nonzero change 3.3232294e-06 ( 5.9575351e-05%) - largest zero change 3.2987491e-06
# 0  Obj 0 Primal inf 14.089699 (6) Dual inf 73.182771 (4)
# 0  Obj 0 Primal inf 14.089699 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -0.65963888
# Optimal - objective value -0.65963888
# Optimal objective -0.6596388805 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 8.3003592
# s_minus_1: 2.5087528
# s_minus_2: 13.329046
# s_minus_3: 33.955476
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c8563722faf14366b8316701f30e1d42-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c8563722faf14366b8316701f30e1d42-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 34.367295 - largest nonzero change 3.1831593e-06 ( 5.5165012e-05%) - largest zero change 3.0381216e-06
# 0  Obj 0 Primal inf 58.940636 (6) Dual inf 67.324803 (4)
# 0  Obj 0 Primal inf 58.940636 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -6.7141077e-11
# Optimal - objective value -6.7141077e-11
# Optimal objective -6.714107684e-11 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 1.1503697e-09
# s_minus_1: 2.4050682e-09
# s_minus_2: 1.3065625e-10
# s_minus_3: 1.3647988e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ed929785f35a4a61b39785a651687c85-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ed929785f35a4a61b39785a651687c85-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 33.736451 - largest nonzero change 2.9502115e-06 ( 6.3214396e-05%) - largest zero change 2.9489563e-06
# 0  Obj 0 Primal inf 16.857099 (6) Dual inf 63.951647 (4)
# 0  Obj 0 Primal inf 16.857099 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.6086
# Optimal - objective value -0.6086
# Optimal objective -0.6086000007 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 9.1653494
# s_minus_1: 0.46149265
# s_minus_2: 15.840041
# s_minus_3: 40.57538
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f0cb46df9f0d44ae801c84a708b3a1ef-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f0cb46df9f0d44ae801c84a708b3a1ef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 39.80393 - largest nonzero change 3.0659512e-06 ( 2.9075269e-05%) - largest zero change 2.8701513e-06
# 0  Obj 0 Primal inf 9.5290537 (6) Dual inf 54.120827 (4)
# 0  Obj 0 Primal inf 9.5290537 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -2.5585134e-10
# Optimal - objective value -2.5585134e-10
# Optimal objective -2.558513376e-10 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 8.4943294e-09
# s_minus_1: 1.3710375e-08
# s_minus_2: -1.1228056e-09
# s_minus_3: 1.3648228e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/412eb5fdceb34359be195b20ce97a533-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/412eb5fdceb34359be195b20ce97a533-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 34.228156 - largest nonzero change 2.6460598e-06 ( 3.0918582e-05%) - largest zero change 2.548825e-06
# 0  Obj 0 Primal inf 10.832233 (6) Dual inf 47.128327 (4)
# 0  Obj 0 Primal inf 10.832233 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.1654859
# Optimal - objective value -0.1654859
# Optimal objective -0.1654858963 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 2.1064966
# s_minus_1: 4.8619474
# s_minus_2: 4.368424
# s_minus_3: 2.1403359
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/515516bedad246c08f54ab2f777cd564-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/515516bedad246c08f54ab2f777cd564-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 29.274081 - largest nonzero change 2.2729862e-06 ( 3.3236512e-05%) - largest zero change 2.2633266e-06
# 0  Obj 0 Primal inf 12.154514 (6) Dual inf 41.651341 (4)
# 0  Obj 0 Primal inf 12.154514 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.30789736
# Optimal - objective value -0.30789736
# Optimal objective -0.3078973646 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.0400435
# s_minus_1: 9.4096197
# s_minus_2: 10.639203
# s_minus_3: 3.4778642
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9b3c8b9a1b444e2baa87489930b66565-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9b3c8b9a1b444e2baa87489930b66565-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 28.913662 - largest nonzero change 2.2458443e-06 ( 3.5817529e-05%) - largest zero change 2.2425559e-06
# 0  Obj 0 Primal inf 13.148624 (6) Dual inf 39.907823 (4)
# 0  Obj 0 Primal inf 13.148624 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.36547506
# Optimal - objective value -0.36547506
# Optimal objective -0.365475064 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.2908455
# s_minus_1: 18.140963
# s_minus_2: 13.601739
# s_minus_3: 4.116866
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e043bd6b16c54d0f884a84d84dd642b3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e043bd6b16c54d0f884a84d84dd642b3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 25.917703 - largest nonzero change 2.0202294e-06 ( 3.6600305e-05%) - largest zero change 2.0120712e-06
# 0  Obj 0 Primal inf 13.775116 (6) Dual inf 35.620271 (4)
# 0  Obj 0 Primal inf 13.775116 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.63970213
# Optimal - objective value -0.63970213
# Optimal objective -0.6397021314 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 10.429994
# s_minus_1: 45.012442
# s_minus_2: 22.313807
# s_minus_3: 7.7918884
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1f0932a04618474d950ce62921bcbb60-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1f0932a04618474d950ce62921bcbb60-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 20.94736 - largest nonzero change 1.6459308e-06 ( 3.9919308e-05%) - largest zero change 1.6397317e-06
# 0  Obj 0 Primal inf 17.416347 (6) Dual inf 31.310194 (4)
# 0  Obj 0 Primal inf 17.416347 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.2359995
# Optimal - objective value -0.2359995
# Optimal objective -0.235999505 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 6.850683
# s_minus_1: 0.070804601
# s_minus_2: 19.783666
# s_minus_3: 1.6508999
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/bc18aa89fb4648548e2717f63a28e7ca-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/bc18aa89fb4648548e2717f63a28e7ca-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 17.576621 - largest nonzero change 1.3920925e-06 ( 4.2153717e-05%) - largest zero change 1.3786931e-06
# 0  Obj 0 Primal inf 20.501817 (6) Dual inf 28.39804 (4)
# 0  Obj 0 Primal inf 20.501817 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.42828018
# Optimal - objective value -0.42828018
# Optimal objective -0.4282801816 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 13.077205
# s_minus_1: 1.0489742
# s_minus_2: 31.729249
# s_minus_3: 10.08109
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b902e7cce35042978775eb91cae45b9d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b902e7cce35042978775eb91cae45b9d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 15.360383 - largest nonzero change 1.2251956e-06 ( 4.0630078e-05%) - largest zero change 1.2150818e-06
# 0  Obj 0 Primal inf 20.345638 (6) Dual inf 26.355234 (4)
# 0  Obj 0 Primal inf 20.345638 (6) Dual inf 1.5519834e+13 (29)
# 10  Obj -1.2735316e-09
# Optimal - objective value -1.2735316e-09
# Optimal objective -1.273531581e-09 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 5.9346954e-08
# s_minus_1: 0.0
# s_minus_2: 1.0233587e-07
# s_minus_3: 1.470232e-08
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1091973906b241a6805b0d6994a4b941-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1091973906b241a6805b0d6994a4b941-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 15.124069 - largest nonzero change 1.2073996e-06 ( 4.4806701e-05%) - largest zero change 1.2037594e-06
# 0  Obj 0 Primal inf 21.12922 (6) Dual inf 26.25105 (4)
# 0  Obj 0 Primal inf 21.12922 (6) Dual inf 1.5519834e+13 (29)
# 7  Obj -0.33035715
# Optimal - objective value -0.33035715
# Optimal objective -0.3303571452 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 15.895423
# s_minus_1: 1.9863973
# s_minus_2: 38.969807
# s_minus_3: 0.55320753
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e2285d00d3634c3b84b148af7993ba2e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e2285d00d3634c3b84b148af7993ba2e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 15.151173 - largest nonzero change 1.2094407e-06 ( 5.1128575e-05%) - largest zero change 1.205058e-06
# 0  Obj 0 Primal inf 22.426207 (6) Dual inf 27.432423 (4)
# 0  Obj 0 Primal inf 22.426207 (6) Dual inf 1.5519834e+13 (29)
# 6  Obj -0.2410394
# Optimal - objective value -0.2410394
# Optimal objective -0.2410394009 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 7.4567333
# s_minus_1: 0.0
# s_minus_2: 47.367693
# s_minus_3: 0.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e7798243aec0475c846215e73586d56a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e7798243aec0475c846215e73586d56a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 11.765721 - largest nonzero change 1.332483e-06 ( 0.00091245738%) - largest zero change 1.254337e-06
# 0  Obj 0 Primal inf 427.98192 (6) Dual inf 19.889052 (4)
# 0  Obj 0 Primal inf 427.98192 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -8.4071e-12
# Optimal - objective value -8.4071e-12
# Optimal objective -8.407100023e-12 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: -1.3343428e-09
# s_minus_1: 0.0
# s_minus_2: -1.1024951e-08
# s_minus_3: 1.365386e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1b487a521baf48798193dd163d7875d7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1b487a521baf48798193dd163d7875d7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 9.7487404 - largest nonzero change 1.120441e-06 ( 0.0006592532%) - largest zero change 1.1063032e-06
# 0  Obj 0 Primal inf 340.57758 (6) Dual inf 18.359848 (4)
# 0  Obj 0 Primal inf 340.57758 (6) Dual inf 1.5519834e+13 (29)
# 9  Obj -0.036794498
# Optimal - objective value -0.036794498
# Optimal objective -0.03679449782 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 0.0
# s_minus_1: 4.4707101
# s_minus_2: 16.804545
# s_minus_3: 0.26206829
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6d7786fc9ce74431bb019cae9f4dc105-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6d7786fc9ce74431bb019cae9f4dc105-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 8.1239504 - largest nonzero change 9.4962935e-07 ( 0.00058146233%) - largest zero change 9.4248045e-07
# 0  Obj 0 Primal inf 327.64067 (6) Dual inf 16.168388 (4)
# 0  Obj 0 Primal inf 327.64067 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -9.7330098e-12
# Optimal - objective value -9.8032914e-12
# Optimal objective -9.803291436e-12 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 4.3990665e-11
# s_minus_1: 5.3869449e-10
# s_minus_2: 0.0
# s_minus_3: 1.364833e-10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c8b41e43dfdc43b0a96667676ca593ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c8b41e43dfdc43b0a96667676ca593ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 6.8241183 - largest nonzero change 8.1298006e-07 ( 0.00052120094%) - largest zero change 8.0608717e-07
# 0  Obj 0 Primal inf 314.30707 (6) Dual inf 14.585609 (4)
# 0  Obj 0 Primal inf 314.30707 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.75490742
# Optimal - objective value -0.75490742
# Optimal objective -0.7549074221 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 118.97117
# s_minus_1: 68.845358
# s_minus_2: 825.36313
# s_minus_3: 4.0572968
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/06e68dbfbdd4444fbb1e43f5fc485da2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/06e68dbfbdd4444fbb1e43f5fc485da2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 170 RHS
# At line 177 BOUNDS
# At line 178 ENDATA
# Problem MODEL has 6 rows, 29 columns and 154 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 29 (0) columns and 154 (0) elements
# Perturbing problem by 0.001% of 6.8241183 - largest nonzero change 8.1298006e-07 ( 0.00049855073%) - largest zero change 8.0608717e-07
# 0  Obj 0 Primal inf 300.60971 (6) Dual inf 14.623783 (4)
# 0  Obj 0 Primal inf 300.60971 (6) Dual inf 1.5519834e+13 (29)
# 8  Obj -0.74265283
# Optimal - objective value -0.74265283
# Optimal objective -0.7426528252 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# s_minus_0: 108.38555
# s_minus_1: 70.386162
# s_minus_2: 762.0937
# s_minus_3: 4.05572

# %%
#Malquits_model.SBM_result.to_csv('SBM_result.csv')

# %%
Malquits_model.SBM_result
# Out:
#               Conpany  Year       Rho
# 0      SONY US Equity  2023  1.000000
# 1      SONY US Equity  2022  1.000000
# 2      SONY US Equity  2021  1.000000
# 3      SONY US Equity  2020  0.761898
# 4      SONY US Equity  2019  0.672425
# 5      AAPl US Equity  2023  0.168278
# 6      AAPl US Equity  2022  1.000000
# 7      AAPl US Equity  2021  0.340361
# 8      AAPl US Equity  2020  1.000000
# 9      AAPl US Equity  2019  0.391400
# 10     DELL US Equity  2023  1.000000
# 11     DELL US Equity  2022  0.834514
# 12     DELL US Equity  2021  0.692103
# 13     DELL US Equity  2020  0.634525
# 14     DELL US Equity  2019  0.360298
# 15      HPE US Equity  2023  0.764000
# 16      HPE US Equity  2022  0.571720
# 17      HPE US Equity  2021  1.000000
# 18      HPE US Equity  2020  0.669643
# 19      HPE US Equity  2019  0.758961
# 20  SAMSUNG KS Equity  2023  1.000000
# 21  SAMSUNG KS Equity  2022  0.963206
# 22  SAMSUNG KS Equity  2021  1.000000
# 23  SAMSUNG KS Equity  2020  0.245093
# 24  SAMSUNG KS Equity  2019  0.257347

# %%
effective_score_list = Malquits_model.Primal_equation_test()
len(effective_score_list)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0e31b199be5744dca2963f470407123d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0e31b199be5744dca2963f470407123d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.057216362 (1) Dual inf 165.77645 (2)
# 0  Obj -0 Primal inf 0.057216362 (1) Dual inf 1.0507489e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4fed25f65f614fd3b5830d51e5c72df3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4fed25f65f614fd3b5830d51e5c72df3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.036940007 (1) Dual inf 149.23711 (2)
# 0  Obj -0 Primal inf 0.036940007 (1) Dual inf 1.621168e+11 (6)
# 9  Obj 0.89527624
# Optimal - objective value 0.89527624
# Optimal objective 0.8952762389 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4b332ff675b64f7db8921ccbea6fd867-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/4b332ff675b64f7db8921ccbea6fd867-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.073522609 (1) Dual inf 171.66562 (2)
# 0  Obj -0 Primal inf 0.073522609 (1) Dual inf 1.044239e+11 (6)
# 6  Obj 2.1904762
# Optimal - objective value 2.1904762
# Optimal objective 2.19047619 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0bdd37733c69458e81dcdcc83fa65886-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0bdd37733c69458e81dcdcc83fa65886-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 149.23711 (2)
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 1.7791917e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8144fbe786c74e56b88edc1bd7464aa3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8144fbe786c74e56b88edc1bd7464aa3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030751319 (1) Dual inf 140.95707 (2)
# 0  Obj -0 Primal inf 0.030751319 (1) Dual inf 6.194043e+10 (6)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0540f91521b04015b902d4715ff0d562-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0540f91521b04015b902d4715ff0d562-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.027164718 (1) Dual inf 853.89448 (2)
# 0  Obj -0 Primal inf 0.027164718 (1) Dual inf 1.1383902e+11 (6)
# 3  Obj 0.98164405
# Optimal - objective value 0.98164405
# Optimal objective 0.9816440543 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/648125cc8d43446f89da42c90c082fb0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/648125cc8d43446f89da42c90c082fb0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.034656211 (1) Dual inf 140.95707 (2)
# 0  Obj -0 Primal inf 0.034656211 (1) Dual inf 6.0622231e+10 (6)
# 6  Obj 1.1751473
# Optimal - objective value 1.1751473
# Optimal objective 1.175147272 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c155901c8cbf48dd80db6006d8df29aa-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c155901c8cbf48dd80db6006d8df29aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 853.89448 (2)
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 1.1519667e+11 (6)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/def8fc841df6448980663e5ee3d2e393-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/def8fc841df6448980663e5ee3d2e393-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.039150934 (1) Dual inf 127.11953 (2)
# 0  Obj -0 Primal inf 0.039150934 (1) Dual inf 6.2432398e+10 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b51cd72175ac4e4698e696c91b7646b1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/b51cd72175ac4e4698e696c91b7646b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.027614721 (1) Dual inf 188.77643 (2)
# 0  Obj -0 Primal inf 0.027614721 (1) Dual inf 1.2026272e+11 (6)
# 7  Obj 0.93395857
# Optimal - objective value 0.93395857
# Optimal objective 0.9339585665 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dcc03e2504aa451b82b50240e1e6c375-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dcc03e2504aa451b82b50240e1e6c375-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.044749075 (1) Dual inf 127.11953 (2)
# 0  Obj -0 Primal inf 0.044749075 (1) Dual inf 6.3872504e+10 (6)
# 6  Obj 1.1282158
# Optimal - objective value 1.1282158
# Optimal objective 1.128215848 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ddc367ef8fe24841a1d1924e53cd9d16-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ddc367ef8fe24841a1d1924e53cd9d16-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 188.77643 (2)
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 1.2217145e+11 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6a8b4e0496a14b22a2cee69595ee4b89-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6a8b4e0496a14b22a2cee69595ee4b89-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.033401665 (1) Dual inf 193.89261 (2)
# 0  Obj -0 Primal inf 0.033401665 (1) Dual inf 5.6012452e+10 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/18601262ab774411a01ef5734e0b1a85-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/18601262ab774411a01ef5734e0b1a85-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.020233946 (1) Dual inf 243.32037 (2)
# 0  Obj -0 Primal inf 0.020233946 (1) Dual inf 7.7906221e+10 (6)
# 5  Obj 1.3364781
# Optimal - objective value 1.3364781
# Optimal objective 1.336478138 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ce59bc0688c84ee8ba8b8bcb30a9a60d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ce59bc0688c84ee8ba8b8bcb30a9a60d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.032192875 (1) Dual inf 193.89261 (2)
# 0  Obj -0 Primal inf 0.032192875 (1) Dual inf 5.6417141e+10 (6)
# 6  Obj 1.1194407
# Optimal - objective value 1.1194407
# Optimal objective 1.119440738 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c5333d152ee34b8f99f22864b47bcd13-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c5333d152ee34b8f99f22864b47bcd13-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 243.32037 (2)
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 9.8546244e+10 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5ab925c060e042f5a24331a63dfdbf3d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5ab925c060e042f5a24331a63dfdbf3d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.01226369 (1) Dual inf 155.66695 (2)
# 0  Obj -0 Primal inf 0.01226369 (1) Dual inf 1.012905e+11 (6)
# 6  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dc594f42da6b413aaf5bcfd2502a37b6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dc594f42da6b413aaf5bcfd2502a37b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0076988115 (1) Dual inf 107.80925 (2)
# 0  Obj -0 Primal inf 0.0076988115 (1) Dual inf 1.0994107e+11 (6)
# 6  Obj 0.58168186
# Optimal - objective value 0.58168186
# Optimal objective 0.5816818581 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5b7cb71d2ed04c26b0a219396ccc4207-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/5b7cb71d2ed04c26b0a219396ccc4207-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.011922894 (1) Dual inf 157.43031 (2)
# 0  Obj -0 Primal inf 0.011922894 (1) Dual inf 1.0320453e+11 (6)
# 6  Obj 1.0191264
# Optimal - objective value 1.0191264
# Optimal objective 1.01912643 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0ebae4c45bd74919a7705bd6f9209738-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0ebae4c45bd74919a7705bd6f9209738-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 107.80925 (2)
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 1.1173613e+11 (6)
# 6  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ac342668a7bf474ea08af2669879c6bc-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ac342668a7bf474ea08af2669879c6bc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 149.23711 (2)
# 0  Obj -0 Primal inf 0.04746765 (1) Dual inf 1.7791917e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6c7822f5dfbf41ae931f7265e62180df-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6c7822f5dfbf41ae931f7265e62180df-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.069096154 (1) Dual inf 121.88417 (2)
# 0  Obj -0 Primal inf 0.069096154 (1) Dual inf 9.301831e+10 (6)
# 8  Obj 0.99986864
# Optimal - objective value 0.99986864
# Optimal objective 0.9998686412 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0d844e39b8d14360b63fc3ebd8374a1b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0d844e39b8d14360b63fc3ebd8374a1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.058815226 (1) Dual inf 149.23711 (2)
# 0  Obj -0 Primal inf 0.058815226 (1) Dual inf 1.9760515e+11 (6)
# 7  Obj 1.5
# Optimal - objective value 1.5
# Optimal objective 1.5 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e908ce6b516a4c37a3d81a081878c267-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e908ce6b516a4c37a3d81a081878c267-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 121.62492 (2)
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 1.1303689e+11 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f57bc34f29b346f2ae99674c45e45f45-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/f57bc34f29b346f2ae99674c45e45f45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 853.89448 (2)
# 0  Obj -0 Primal inf 0.030075873 (1) Dual inf 1.1519667e+11 (6)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dbafb48b4ee245fe98bab6e176fffcc0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/dbafb48b4ee245fe98bab6e176fffcc0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.031049151 (1) Dual inf 102.92698 (2)
# 0  Obj -0 Primal inf 0.031049151 (1) Dual inf 6.257413e+10 (6)
# 5  Obj 0.99082256
# Optimal - objective value 0.99082256
# Optimal objective 0.9908225609 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/03dadbf3e4a4422a8a63c217f6facc0d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/03dadbf3e4a4422a8a63c217f6facc0d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.032677924 (1) Dual inf 853.89448 (2)
# 0  Obj -0 Primal inf 0.032677924 (1) Dual inf 1.14972e+11 (6)
# 4  Obj 1.1396552
# Optimal - objective value 1.1396552
# Optimal objective 1.139655172 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/62b51b301c9b4a8080e00f145b52749a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/62b51b301c9b4a8080e00f145b52749a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.033735405 (1) Dual inf 103.69567 (2)
# 0  Obj -0 Primal inf 0.033735405 (1) Dual inf 6.6063808e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8d2d0449d2484eb5bd56058686b7b134-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/8d2d0449d2484eb5bd56058686b7b134-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 188.77643 (2)
# 0  Obj -0 Primal inf 0.030897753 (1) Dual inf 1.2217145e+11 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0c4d987b60bf44d6b443049cee7706e8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0c4d987b60bf44d6b443049cee7706e8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.044106891 (1) Dual inf 130.02703 (2)
# 0  Obj -0 Primal inf 0.044106891 (1) Dual inf 6.0979004e+10 (6)
# 7  Obj 0.9876881
# Optimal - objective value 0.9876881
# Optimal objective 0.9876880985 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ad27fa6d38e4400184391c56a2a84c46-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ad27fa6d38e4400184391c56a2a84c46-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.033544507 (1) Dual inf 188.77643 (2)
# 0  Obj -0 Primal inf 0.033544507 (1) Dual inf 1.2281625e+11 (6)
# 8  Obj 1.1424149
# Optimal - objective value 1.1424149
# Optimal objective 1.142414931 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/91a7d3a5e5bd453cadf93a796053056b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/91a7d3a5e5bd453cadf93a796053056b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.047602393 (1) Dual inf 130.02703 (2)
# 0  Obj -0 Primal inf 0.047602393 (1) Dual inf 6.0927599e+10 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/63ebd955c29647f9a28f62d65976ca29-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/63ebd955c29647f9a28f62d65976ca29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 243.32037 (2)
# 0  Obj -0 Primal inf 0.022622144 (1) Dual inf 9.8546244e+10 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/76d546795d464214ad85582d2747e898-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/76d546795d464214ad85582d2747e898-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.032293378 (1) Dual inf 172.51705 (2)
# 0  Obj -0 Primal inf 0.032293378 (1) Dual inf 5.3345001e+10 (6)
# 6  Obj 1.1787081
# Optimal - objective value 1.1787081
# Optimal objective 1.178708105 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/eee53f0c802f495186458a196ff3f0f9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/eee53f0c802f495186458a196ff3f0f9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.021393672 (1) Dual inf 243.32037 (2)
# 0  Obj -0 Primal inf 0.021393672 (1) Dual inf 1.0403657e+11 (6)
# 6  Obj 1.1077401
# Optimal - objective value 1.1077401
# Optimal objective 1.107740139 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a83330bc4ae74f86aba26b3fd0b775ba-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a83330bc4ae74f86aba26b3fd0b775ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.029390737 (1) Dual inf 172.51705 (2)
# 0  Obj -0 Primal inf 0.029390737 (1) Dual inf 5.2152088e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7c860fa185954e65867b7b3a38c614d2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/7c860fa185954e65867b7b3a38c614d2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 107.80925 (2)
# 0  Obj -0 Primal inf 0.007523317 (1) Dual inf 1.1173613e+11 (6)
# 6  Obj 0.58953838
# Optimal - objective value 0.58953838
# Optimal objective 0.5895383766 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e82fca8c8f7444048ba92de284ed9e03-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e82fca8c8f7444048ba92de284ed9e03-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.010745034 (1) Dual inf 244.22549 (2)
# 0  Obj -0 Primal inf 0.010745034 (1) Dual inf 8.8289425e+10 (6)
# 6  Obj 0.99242429
# Optimal - objective value 0.99242429
# Optimal objective 0.9924242891 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/84e388ad6a084fc19454fe0998bbbc24-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/84e388ad6a084fc19454fe0998bbbc24-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0080559319 (1) Dual inf 107.61194 (2)
# 0  Obj -0 Primal inf 0.0080559319 (1) Dual inf 1.1473131e+11 (6)
# 6  Obj 0.6430215
# Optimal - objective value 0.6430215
# Optimal objective 0.643021504 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/be981309681a4dec92590422ee309603-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/be981309681a4dec92590422ee309603-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.011511494 (1) Dual inf 244.22549 (2)
# 0  Obj -0 Primal inf 0.011511494 (1) Dual inf 9.4215987e+10 (6)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2aa26a0bd2fe4520a6d0e115bbd1f7ca-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2aa26a0bd2fe4520a6d0e115bbd1f7ca-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 121.62492 (2)
# 0  Obj -0 Primal inf 0.08561421 (1) Dual inf 1.1303689e+11 (6)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d3991f7a6a1c4dd9a29e248b0baa97bd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/d3991f7a6a1c4dd9a29e248b0baa97bd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.066432348 (1) Dual inf 179.47376 (2)
# 0  Obj -0 Primal inf 0.066432348 (1) Dual inf 9.3074915e+10 (6)
# 9  Obj 2.0458608
# Optimal - objective value 2.0458608
# Optimal objective 2.045860804 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e78700ed7e1b4de3aa68b40ddd45c9c1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/e78700ed7e1b4de3aa68b40ddd45c9c1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.10491421 (1) Dual inf 150.99289 (2)
# 0  Obj -0 Primal inf 0.10491421 (1) Dual inf 1.3603326e+11 (6)
# 9  Obj 2
# Optimal - objective value 2
# Optimal objective 2 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6e94831e0d514bd8818ff36d86402cf9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/6e94831e0d514bd8818ff36d86402cf9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# ...
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.077318594 (1) Dual inf 27.308701 (2)
# 0  Obj -0 Primal inf 0.077318594 (1) Dual inf 2.2704416e+11 (6)
# 7  Obj 2.1818182
# Optimal - objective value 2.1818182
# Optimal objective 2.181818182 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/83afa815b8d4497b9e1d06b213d37c0e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/83afa815b8d4497b9e1d06b213d37c0e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.027300822 (1) Dual inf 127.59169 (2)
# 0  Obj -0 Primal inf 0.027300822 (1) Dual inf 7.2209498e+10 (6)
# 6  Obj 0.92935513
# Optimal - objective value 0.92935513
# Optimal objective 0.9293551272 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c0324c06d541413e986340da892b8481-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/c0324c06d541413e986340da892b8481-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.05356848 (1) Dual inf 27.308701 (2)
# 0  Obj -0 Primal inf 0.05356848 (1) Dual inf 1.8769948e+11 (6)
# 7  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a958e3e867384bcbbef8b1b2dbe56928-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/a958e3e867384bcbbef8b1b2dbe56928-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.049356083 (1) Dual inf 182.39697 (2)
# 0  Obj -0 Primal inf 0.049356083 (1) Dual inf 6.4414257e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ca3fa1813dfb4cc6a62f3c063b995fc6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ca3fa1813dfb4cc6a62f3c063b995fc6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.075351282 (1) Dual inf 46.731536 (2)
# 0  Obj -0 Primal inf 0.075351282 (1) Dual inf 1.1566068e+11 (6)
# 7  Obj 0.94074035
# Optimal - objective value 0.94074035
# Optimal objective 0.9407403548 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/636eeeab38854207ae1ace1f90c467b1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/636eeeab38854207ae1ace1f90c467b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.054859363 (1) Dual inf 182.39697 (2)
# 0  Obj -0 Primal inf 0.054859363 (1) Dual inf 6.2974225e+10 (6)
# 5  Obj 1.218345
# Optimal - objective value 1.218345
# Optimal objective 1.218345003 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/46a22171b0394c859e1ec72973c83965-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/46a22171b0394c859e1ec72973c83965-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.089874351 (1) Dual inf 46.731536 (2)
# 0  Obj -0 Primal inf 0.089874351 (1) Dual inf 1.1592667e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/19e2812f9ce141d0aa9efbe2e478cc19-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/19e2812f9ce141d0aa9efbe2e478cc19-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.02833726 (1) Dual inf 210.98254 (2)
# 0  Obj -0 Primal inf 0.02833726 (1) Dual inf 5.663204e+10 (6)
# 7  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9a30d8e8e44e4f2084b17b4c95ff6ec6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/9a30d8e8e44e4f2084b17b4c95ff6ec6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.03499257 (1) Dual inf 53.457793 (2)
# 0  Obj -0 Primal inf 0.03499257 (1) Dual inf 1.0503987e+11 (6)
# 6  Obj 1.1779119
# Optimal - objective value 1.1779119
# Optimal objective 1.177911926 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1cfb312876fb4a2795ed457a6cfc85a9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/1cfb312876fb4a2795ed457a6cfc85a9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.035502913 (1) Dual inf 210.98254 (2)
# 0  Obj -0 Primal inf 0.035502913 (1) Dual inf 6.006091e+10 (6)
# 7  Obj 1.0776213
# Optimal - objective value 1.0776213
# Optimal objective 1.077621253 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/92bf44d1015c4d0caa7a3098123693ad-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/92bf44d1015c4d0caa7a3098123693ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.041849486 (1) Dual inf 53.457793 (2)
# 0  Obj -0 Primal inf 0.041849486 (1) Dual inf 9.848024e+10 (6)
# 6  Obj 0.99328206
# Optimal - objective value 0.99328206
# Optimal objective 0.9932820586 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2751e30154e74da2b6cb36991c495ac4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/2751e30154e74da2b6cb36991c495ac4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.010872132 (1) Dual inf 311.85375 (2)
# 0  Obj -0 Primal inf 0.010872132 (1) Dual inf 9.7939907e+10 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/55da193ad1dd417b9e2678199dde5f85-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/55da193ad1dd417b9e2678199dde5f85-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.005369593 (1) Dual inf 75.981579 (2)
# 0  Obj -0 Primal inf 0.005369593 (1) Dual inf 2.1968875e+11 (6)
# 6  Obj 1.1766677
# Optimal - objective value 1.1766677
# Optimal objective 1.176667681 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ccfeb7e62e9744598a98671c0981c4ed-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/ccfeb7e62e9744598a98671c0981c4ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.010640743 (1) Dual inf 320.13087 (2)
# 0  Obj -0 Primal inf 0.010640743 (1) Dual inf 1.0789488e+11 (6)
# 9  Obj 1.2068966
# Optimal - objective value 1.2068966
# Optimal objective 1.206896552 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yanhanjun/Library/Python/3.9/lib/python/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0a06c932e8ec4d0697a3c8c0145b0e83-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8t/3xrvdszj1g75llc2jb40dnvw0000gn/T/0a06c932e8ec4d0697a3c8c0145b0e83-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 48 RHS
# At line 55 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 6 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 6 (0) columns and 34 (0) elements
# 0  Obj -0 Primal inf 0.0052159818 (1) Dual inf 75.981579 (2)
# 0  Obj -0 Primal inf 0.0052159818 (1) Dual inf 2.6810599e+11 (6)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# 20

# %%
effective_score_list
# Out:
# [0.6393067136348877,
#  0.9139677422257949,
#  0.9098456160205416,
#  1.0926482517653393,
#  0.3419769584495848,
#  0.8164429373788556,
#  0.9324191759357331,
#  0.9298180749797368,
#  1.0315355158507589,
#  2.744528901778638,
#  1.0114002473096513,
#  0.7305656297786167,
#  0.8977642542293816,
#  0.9934009816534477,
#  0.9073310329920746,
#  0.0697340097962083,
#  1.5322105361360847,
#  0.8787184434887209,
#  1.0349806088711757,
#  0.9873971550590839]

# %%
Malquits_model.result_FromCRSPrimal.to_csv("Result_FromCRSPrimal.csv")

# %%
len(effective_score_list)
# Out:
# 20

# %%
Malquits_model.Malquist_primal_model[79]
# Out:
# Efficiency_Calculation_from_PrimalEquation:
# MAXIMIZE
# 725.33*u_0 + 4.95*u_1 + 0.0
# SUBJECT TO
# _C1: - 283.35 u_0 - 5.09 u_1 + 96.22 v_0 + 89.9 v_1 + 0.01 v_2 + 3.3 v_3 >= 0
#
# _C2: - 44.65 u_0 - 5.66 u_1 + 11.68 v_0 + 16.8 v_1 + 16.96 v_2 + 44.7 v_3 >= 0
#
# _C3: - 349.49 u_0 - 4.78 u_1 + 10.62 v_0 + 49.7 v_1 + 16.88 v_2 + 9.6 v_3 >= 0
#
# _C4: - 438.65 u_0 - 4.77 u_1 + 20.18 v_0 + 62.45 v_1 + 40.97 v_2 + 13.7 v_3
#  >= 0
#
# _C5: - 725.33 u_0 - 4.95 u_1 + 198.52 v_0 + 74.5 v_1 + 1637.59 v_2 + 2.9 v_3
#  >= 0
#
# _C6: 198.52 v_0 + 74.5 v_1 + 1637.59 v_2 + 2.9 v_3 = 1
#
# VARIABLES
# u_0 Continuous
# u_1 Continuous
# v_0 Continuous
# v_1 Continuous
# v_2 Continuous
# v_3 Continuous

# %%
Malquits_model.Malquist_primal_model[1]
# Out:
# Efficiency_Calculation_from_PrimalEquation:
# MAXIMIZE
# 237.57*u_0 + 4.79*u_1 + 0.0
# SUBJECT TO
# _C1: - 237.57 u_0 - 4.79 u_1 + 40.61 v_0 + 95.8 v_1 + 10.176 v_2 + 2.1 v_3
#  >= 0
#
# _C2: - 99.39 u_0 - 512 u_1 + 12.3 v_0 + 14.6 v_1 + 19.83 v_2 + 36.7 v_3 >= 0
#
# _C3: - 307.01 u_0 - 3.56 u_1 + 14.62 v_0 + 61.8 v_1 + 28.43 v_2 + 12.55 v_3
#  >= 0
#
# _C4: - 396.7 u_0 - 4.21 u_1 + 27.95 v_0 + 58.4 v_1 + 58.13 v_2 + 11.45 v_3
#  >= 0
#
# _C5: - 167.67 u_0 - 4.98 u_1 + 164.75 v_0 + 86.1 v_1 + 1202.38 v_2 + 5 v_3
#  >= 0
#
# _C6: 40.76 v_0 + 98.1 v_1 + 13.568 v_2 + 4.6 v_3 = 1
#
# VARIABLES
# u_0 Continuous
# u_1 Continuous
# v_0 Continuous
# v_1 Continuous
# v_2 Continuous
# v_3 Continuous
